# %%
import pandas as pd
import all_function as af
#pd.read_excel('database/Biohub authors.xlsx')

import re
import os
import unicodedata
# from datetime import date,time
import datetime
import pandas as pd
import numpy as np

import datacompy
from os.path import exists as file_exists

# %%
import importlib
import all_function as af #import the module here, so that it can be reloaded.
importlib.reload(af)
start=(datetime.date.today() - datetime.timedelta(days=5)).strftime('%Y-%m-%d')
end=(datetime.date.today() -
    datetime.timedelta(days=1)).strftime('%Y-%m-%d')
Keyword='biohub'
df5=af.Bibliometrics_Collect(start)
# Out:
# BioMedrxiv: Fetching search results 1 to 10...
# BioMedrxiv: Fetched 2 records in 7.4 seconds.
# Arxiv: Fetching search results 1 to 9...
# Arxiv: Fetched 0 records in 0.3 seconds.
# Pubmed: Fetched 4 records in 2.8 seconds.
# Pubmed: Fetched 1 records in 0.6 seconds.
# Pubmed: Fetched 1 records in 0.6 seconds.
# ORCID ID found for "Gawad, Chuck" in Pubmed 36163278 :
#  https://orcid.org/0000-0002-4728-8203
#
# ORCID ID found for "Blish, Catherine" in Pubmed 36074821 :
#  https://orcid.org/0000-0001-6946-7627
#
# ORCID ID found for "Pisco, Angela" in Pubmed 36050550 :
#  https://orcid.org/0000-0003-0142-2355
#
# ORCID ID found for "Ott, Melanie" in Pubmed 35945353 :
#  https://orcid.org/0000-0001-8374-669X
#
# ORCID ID found for "Jerby-Arnon, Livnat" in Pubmed 35513526 :
#  https://orcid.org/0000-0002-4037-386X
#
# Mismatched ORCID ID found for "Marqusee, Susan" in Pubmed 36173161
#   ORCID ID in publication: 0000-0001-7648-2163
#   ORCID ID from "Biohub authors.xlsx" file: https://orcid.org/0000-0001-7648-2163
#
# Mismatched ORCID ID found for "Marqusee, Susan" in Pubmed 36173161
#   ORCID ID in publication: 0000-0001-7648-2163
#   ORCID ID from "Biohub authors.xlsx" file: https://orcid.org/0000-0001-7648-2163
#
# Mismatched ORCID ID found for "Marqusee, Susan" in Pubmed 36173161
#   ORCID ID in publication: 0000-0001-7648-2163
#   ORCID ID from "Biohub authors.xlsx" file: https://orcid.org/0000-0001-7648-2163
#
# Mismatched ORCID ID found for "Marqusee, Susan" in Pubmed 36173161
#   ORCID ID in publication: 0000-0001-7648-2163
#   ORCID ID from "Biohub authors.xlsx" file: https://orcid.org/0000-0001-7648-2163
#
# Mismatched ORCID ID found for "Marqusee, Susan" in Pubmed 36173161
#   ORCID ID in publication: 0000-0001-7648-2163
#   ORCID ID from "Biohub authors.xlsx" file: https://orcid.org/0000-0001-7648-2163
#
# ORCID ID found for "Jerby-Arnon, Livnat" in Pubmed 35513526 :
#  http://orcid.org/0000-0002-4037-386X
#
# Mismatched ORCID ID found for "Banfield, Jill" in Pubmed 36261517
#   ORCID ID in publication: http://orcid.org/0000-0001-8203-8771
#   ORCID ID from "Biohub authors.xlsx" file: https://orcid.org/0000-0001-8203-8771
#
# Mismatched ORCID ID found for "Fordyce, Polly" in Pubmed 36064771
#   ORCID ID in publication: 0000-0002-9505-0638
#   ORCID ID from "Biohub authors.xlsx" file: https://orcid.org/0000-0002-9505-0638
#
# Mismatched ORCID ID found for "Greenleaf, Will" in Pubmed 36171288
#   ORCID ID in publication: http://orcid.org/0000-0003-1409-3095
#   ORCID ID from "Biohub authors.xlsx" file: https://orcid.org/0000-0003-1409-3095
#
# Mismatched ORCID ID found for "Huang, Bo" in Pubmed 35773394
#   ORCID ID in publication: http://orcid.org/0000-0001-8476-1138
#   ORCID ID from "Biohub authors.xlsx" file: https://orcid.org/0000-0003-1704-4141
#
# Mismatched ORCID ID found for "Leskovec, Jure" in Pubmed 36131149
#   ORCID ID in publication: http://orcid.org/0000-0002-5411-923X
#   ORCID ID from "Biohub authors.xlsx" file: https://orcid.org/0000-0002-5411-923X
#
# Mismatched ORCID ID found for "Pollard, Katie" in Pubmed 36138165
#   ORCID ID in publication: 0000-0002-9870-6196
#   ORCID ID from "Biohub authors.xlsx" file: https://orcid.org/0000-0002-9870-6196
#
# Mismatched ORCID ID found for "Turnbaugh, Peter" in Pubmed 36138165
#   ORCID ID in publication: 0000-0002-0888-2875
#   ORCID ID from "Biohub authors.xlsx" file: https://orcid.org/0000-0002-0888-2875
#
# Mismatched ORCID ID found for "Song, Yun" in Pubmed 36008371
#   ORCID ID in publication: https://orcid.org/0000-0001-8319-7176
#   ORCID ID from "Biohub authors.xlsx" file: https://orcid.org/0000-0002-0734-9868
#
# Mismatched ORCID ID found for "Xu, Ke" in Pubmed 36116023
#   ORCID ID in publication: http://orcid.org/0000-0003-4444-0801
#   ORCID ID from "Biohub authors.xlsx" file: https://orcid.org/0000-0002-2788-194X
#
# Mismatched ORCID ID found for "Xu, Ke" in Pubmed 36000517
#   ORCID ID in publication: https://orcid.org/0000-0002-5361-6277
#   ORCID ID from "Biohub authors.xlsx" file: https://orcid.org/0000-0002-2788-194X
#
# Mismatched ORCID ID found for "Xu, Ke" in Pubmed 35848930
#   ORCID ID in publication: 0000-0003-4364-3770
#   ORCID ID from "Biohub authors.xlsx" file: https://orcid.org/0000-0002-2788-194X
#
# Mismatched ORCID ID found for "Xu, Ke" in Pubmed 35570744
#   ORCID ID in publication: 0000-0002-2453-4475
#   ORCID ID from "Biohub authors.xlsx" file: https://orcid.org/0000-0002-2788-194X
#
# Mismatched ORCID ID found for "Xu, Ke" in Pubmed 33165830
#   ORCID ID in publication: http://orcid.org/0000-0002-9969-3681
#   ORCID ID from "Biohub authors.xlsx" file: https://orcid.org/0000-0002-2788-194X
#
# ORCID ID found for "Pisco, Angela" in Pubmed 36050550 :
#  http://orcid.org/0000-0003-0142-2355
#
# ORCID ID found for "Palumbi, Steve" in Pubmed 36114282 :
#  0000-0001-5195-1947
#
# ORCID ID found for "Yu, Bin" in Pubmed 35933696 :
#  https://orcid.org/0000-0002-0397-6610
#
# Mismatched ORCID ID found for "Pollard, Katie" in Pubmed 36138165
#   ORCID ID in publication: 0000-0002-9870-6196
#   ORCID ID from "Biohub authors.xlsx" file: https://orcid.org/0000-0002-9870-6196
#
# Mismatched ORCID ID found for "Turnbaugh, Peter" in Pubmed 36138165
#   ORCID ID in publication: 0000-0002-0888-2875
#   ORCID ID from "Biohub authors.xlsx" file: https://orcid.org/0000-0002-0888-2875
#
# ORCID ID found for "Pisco, Angela" in Pubmed 36050550 :
#  http://orcid.org/0000-0003-0142-2355
#
# Mismatched ORCID ID found for "DeRisi, Joe" in Pubmed 36252253
#   ORCID ID in publication: 0000-0002-4611-9205
#   ORCID ID from "Biohub authors.xlsx" file: https://orcid.org/0000-0002-4611-9205
#
# Mismatched ORCID ID found for "Huang, KC" in Pubmed 36191183
#   ORCID ID in publication: 0000-0002-8043-8138
#   ORCID ID from "Biohub authors.xlsx" file: https://orcid.org/0000-0002-8043-8138
#
# Mismatched ORCID ID found for "Banfield, Jill" in Pubmed 36175428
#   ORCID ID in publication: http://orcid.org/0000-0001-8203-8771
#   ORCID ID from "Biohub authors.xlsx" file: https://orcid.org/0000-0001-8203-8771
#
# Mismatched ORCID ID found for "Bateup, Helen" in Pubmed 36171373
#   ORCID ID in publication: http://orcid.org/0000-0002-0135-0972
#   ORCID ID from "Biohub authors.xlsx" file: https://orcid.org/0000-0002-0135-0972
#
# Mismatched ORCID ID found for "Ye, Jimmie" in Pubmed 36171194
#   ORCID ID in publication: http://orcid.org/0000-0001-6560-3783
#   ORCID ID from "Biohub authors.xlsx" file: https://orcid.org/0000-0001-6560-3783
#
# Mismatched ORCID ID found for "Smolke, Christina" in Pubmed 36166456
#   ORCID ID in publication: 0000-0002-5449-8495
#   ORCID ID from "Biohub authors.xlsx" file: https://orcid.org/0000-0002-5449-8495
#
# ORCID ID found for "Gawad, Chuck" in Pubmed 36163278 :
#  http://orcid.org/0000-0002-4728-8203
#
# Mismatched ORCID ID found for "Kim, Peter" in Pubmed 36161911
#   ORCID ID in publication: 0000-0001-6503-4541
#   ORCID ID from "Biohub authors.xlsx" file: https://orcid.org/0000-0001-6503-4541
#
# Mismatched ORCID ID found for "Xu, Ke" in Pubmed 36153973
#   ORCID ID in publication: 0000-0002-2788-194X
#   ORCID ID from "Biohub authors.xlsx" file: https://orcid.org/0000-0002-2788-194X
#
# Mismatched ORCID ID found for "Pollard, Katie" in Pubmed 36138165
#   ORCID ID in publication: 0000-0002-9870-6196
#   ORCID ID from "Biohub authors.xlsx" file: https://orcid.org/0000-0002-9870-6196
#
# Mismatched ORCID ID found for "Turnbaugh, Peter" in Pubmed 36138165
#   ORCID ID in publication: 0000-0002-0888-2875
#   ORCID ID from "Biohub authors.xlsx" file: https://orcid.org/0000-0002-0888-2875
#
# ORCID ID found for "Blish, Catherine" in Pubmed 36137009 :
#  0000-0001-6946-7627
#
# ORCID ID found for "McCutcheon, Krista" in Pubmed 36126074 :
#  0000-0003-1942-5175
#
# ORCID ID found for "Wong, Joan" in Pubmed 36126074 :
#  0000-0002-7849-6320
#
# ORCID ID found for "Pak, John" in Pubmed 36126074 :
#  0000-0002-2998-9735
#
# Mismatched ORCID ID found for "Smolke, Christina" in Pubmed 36107884
#   ORCID ID in publication: 0000-0002-5449-8495
#   ORCID ID from "Biohub authors.xlsx" file: https://orcid.org/0000-0002-5449-8495
#
# Mismatched ORCID ID found for "Soh, Tom" in Pubmed 36097164
#   ORCID ID in publication: 0000-0001-9443-857X
#   ORCID ID from "Biohub authors.xlsx" file: https://orcid.org/0000-0001-9443-857X
#
# Mismatched ORCID ID found for "Kim, Peter" in Pubmed 36076082
#   ORCID ID in publication: http://orcid.org/0000-0001-6503-4541
#   ORCID ID from "Biohub authors.xlsx" file: https://orcid.org/0000-0001-6503-4541
#
# ORCID ID found for "Ott, Melanie" in Pubmed 36075902 :
#  0000-0002-5697-1274
#
# Mismatched ORCID ID found for "Puschnik, Andreas" in Pubmed 36074821
#   ORCID ID in publication: 0000-0002-9605-9458
#   ORCID ID from "Biohub authors.xlsx" file: https://orcid.org/0000-0002-9605-9458
#
# ORCID ID found for "Blish, Catherine" in Pubmed 36074821 :
#  0000-0001-6946-7627
#
# Mismatched ORCID ID found for "Huang, KC" in Pubmed 36069446
#   ORCID ID in publication: 0000-0002-8043-8138
#   ORCID ID from "Biohub authors.xlsx" file: https://orcid.org/0000-0002-8043-8138
#
# Mismatched ORCID ID found for "Huang, KC" in Pubmed 36067229
#   ORCID ID in publication: 0000-0002-8043-8138
#   ORCID ID from "Biohub authors.xlsx" file: https://orcid.org/0000-0002-8043-8138
#
# ORCID ID found for "Roybal, Kole" in Pubmed 36066491 :
#  0000-0003-3030-7954
#
# Mismatched ORCID ID found for "Fordyce, Polly" in Pubmed 36064771
#   ORCID ID in publication: 0000-0002-9505-0638
#   ORCID ID from "Biohub authors.xlsx" file: https://orcid.org/0000-0002-9505-0638
#
# ORCID ID found for "Pisco, Angela" in Pubmed 36050550 :
#  http://orcid.org/0000-0003-0142-2355
#
# Mismatched ORCID ID found for "Marson, Alex" in Pubmed 36002574
#   ORCID ID in publication: http://orcid.org/0000-0002-2734-5776
#   ORCID ID from "Biohub authors.xlsx" file: https://orcid.org/0000-0002-2734-5776
#
# Mismatched ORCID ID found for "Poon, Ada" in Pubmed 35995855
#   ORCID ID in publication: 0000-0003-2647-6069
#   ORCID ID from "Biohub authors.xlsx" file: https://orcid.org/0000-0003-2647-6069
#
# ORCID ID found for "Blish, Catherine" in Pubmed 35982307 :
#  http://orcid.org/0000-0001-6946-7627
#
# ORCID ID found for "Ott, Melanie" in Pubmed 35945353 :
#  0000-0001-8374-669X
#
# ORCID ID found for "Srivastava, Deepak" in Pubmed 35938400 :
#  0000-0002-3480-5953
#
# ORCID ID found for "Dumont, Sophie" in Pubmed 35880301 :
#  0000-0002-8283-1523
#
# Mismatched ORCID ID found for "Reiter, Jeremy" in Pubmed 35793002
#   ORCID ID in publication: 0000-0002-6512-320X
#   ORCID ID from "Biohub authors.xlsx" file: https://orcid.org/0000-0002-6512-320X
#
# Mismatched ORCID ID found for "Turnbaugh, Peter" in Pubmed 35668713
#   ORCID ID in publication: 0000-0002-0888-2875
#   ORCID ID from "Biohub authors.xlsx" file: https://orcid.org/0000-0002-0888-2875
#
# ORCID ID found for "Jerby-Arnon, Livnat" in Pubmed 35513526 :
#  http://orcid.org/0000-0002-4037-386X
#
# Mismatched ORCID ID found for "Yosef, Nir" in Pubmed 35449415
#   ORCID ID in publication: 0000-0001-9004-1225
#   ORCID ID from "Biohub authors.xlsx" file: https://orcid.org/0000-0001-9004-1225
#
# ORCID ID found for "Dumont, Sophie" in Pubmed 36346735 :
#  https://orcid.org/0000-0002-8283-1523
#
# Mismatched ORCID ID found for "Turnbaugh, Peter" in Pubmed 36333489
#   ORCID ID in publication: http://orcid.org/0000-0002-0888-2875
#   ORCID ID from "Biohub authors.xlsx" file: https://orcid.org/0000-0002-0888-2875
#
# ORCID ID found for "Roybal, Kole" in Pubmed 36066491 :
#  0000-0003-3030-7954
#
# ORCID ID found for "Dumont, Sophie" in Pubmed 36346735 :
#  https://orcid.org/0000-0002-8283-1523
#
# Mismatched ORCID ID found for "Turnbaugh, Peter" in Pubmed 36333489
#   ORCID ID in publication: http://orcid.org/0000-0002-0888-2875
#   ORCID ID from "Biohub authors.xlsx" file: https://orcid.org/0000-0002-0888-2875
#
# ORCID ID found for "Roybal, Kole" in Pubmed 36066491 :
#  0000-0003-3030-7954
#
# Fetch done.

# %% [markdown]
# # 用来重置base dataset的

# %%
# start='2022-09-01'
# end='2022-09-10'
# af.Pubmed_search2(start,end)
start='2022-09-01'
end='2022-10-10'
base=af.Bibliometrics_Collect(start,end)
base.fillna('', inplace=True)
base.to_csv('database/basedb.csv', encoding='utf-8-sig',index=False)
# Out:
# BioMedrxiv: Fetching search results 1 to 10...
# BioMedrxiv: Fetching search results 11 to 20...
# BioMedrxiv: Fetching search results 21 to 30...
# BioMedrxiv: Fetching search results 31 to 40...
# BioMedrxiv: Fetched 33 records in 129.2 seconds.
# Arxiv: Fetching search results 1 to 9...
# Arxiv: Fetching search results 11 to 19...
# Arxiv: Fetched 10 records in 9.8 seconds.
# Pubmed: Fetched 73 records in 25.0 seconds.
# ORCID ID found for "Gawad, Chuck" in Pubmed 36163278 :
#  https://orcid.org/0000-0002-4728-8203
#
# ORCID ID found for "Blish, Catherine" in Pubmed 36074821 :
#  https://orcid.org/0000-0001-6946-7627
#
# ORCID ID found for "Pisco, Angela" in Pubmed 36050550 :
#  https://orcid.org/0000-0003-0142-2355
#
# ORCID ID found for "Ott, Melanie" in Pubmed 35945353 :
#  https://orcid.org/0000-0001-8374-669X
#
# ORCID ID found for "Jerby-Arnon, Livnat" in Pubmed 35513526 :
#  https://orcid.org/0000-0002-4037-386X
#
# Mismatched ORCID ID found for "Marqusee, Susan" in Pubmed 36173161
#   ORCID ID in publication: 0000-0001-7648-2163
#   ORCID ID from "Biohub authors.xlsx" file: https://orcid.org/0000-0001-7648-2163
#
# Mismatched ORCID ID found for "Marqusee, Susan" in Pubmed 36173161
#   ORCID ID in publication: 0000-0001-7648-2163
#   ORCID ID from "Biohub authors.xlsx" file: https://orcid.org/0000-0001-7648-2163
#
# Mismatched ORCID ID found for "Marqusee, Susan" in Pubmed 36173161
#   ORCID ID in publication: 0000-0001-7648-2163
#   ORCID ID from "Biohub authors.xlsx" file: https://orcid.org/0000-0001-7648-2163
#
# Mismatched ORCID ID found for "Marqusee, Susan" in Pubmed 36173161
#   ORCID ID in publication: 0000-0001-7648-2163
#   ORCID ID from "Biohub authors.xlsx" file: https://orcid.org/0000-0001-7648-2163
#
# Mismatched ORCID ID found for "Marqusee, Susan" in Pubmed 36173161
#   ORCID ID in publication: 0000-0001-7648-2163
#   ORCID ID from "Biohub authors.xlsx" file: https://orcid.org/0000-0001-7648-2163
#
# ORCID ID found for "Jerby-Arnon, Livnat" in Pubmed 35513526 :
#  http://orcid.org/0000-0002-4037-386X
#
# Mismatched ORCID ID found for "Banfield, Jill" in Pubmed 36261517
#   ORCID ID in publication: http://orcid.org/0000-0001-8203-8771
#   ORCID ID from "Biohub authors.xlsx" file: https://orcid.org/0000-0001-8203-8771
#
# Mismatched ORCID ID found for "Fordyce, Polly" in Pubmed 36064771
#   ORCID ID in publication: 0000-0002-9505-0638
#   ORCID ID from "Biohub authors.xlsx" file: https://orcid.org/0000-0002-9505-0638
#
# Mismatched ORCID ID found for "Greenleaf, Will" in Pubmed 36171288
#   ORCID ID in publication: http://orcid.org/0000-0003-1409-3095
#   ORCID ID from "Biohub authors.xlsx" file: https://orcid.org/0000-0003-1409-3095
#
# Mismatched ORCID ID found for "Huang, Bo" in Pubmed 35773394
#   ORCID ID in publication: http://orcid.org/0000-0001-8476-1138
#   ORCID ID from "Biohub authors.xlsx" file: https://orcid.org/0000-0003-1704-4141
#
# Mismatched ORCID ID found for "Leskovec, Jure" in Pubmed 36131149
#   ORCID ID in publication: http://orcid.org/0000-0002-5411-923X
#   ORCID ID from "Biohub authors.xlsx" file: https://orcid.org/0000-0002-5411-923X
#
# Mismatched ORCID ID found for "Pollard, Katie" in Pubmed 36138165
#   ORCID ID in publication: 0000-0002-9870-6196
#   ORCID ID from "Biohub authors.xlsx" file: https://orcid.org/0000-0002-9870-6196
#
# Mismatched ORCID ID found for "Turnbaugh, Peter" in Pubmed 36138165
#   ORCID ID in publication: 0000-0002-0888-2875
#   ORCID ID from "Biohub authors.xlsx" file: https://orcid.org/0000-0002-0888-2875
#
# Mismatched ORCID ID found for "Song, Yun" in Pubmed 36008371
#   ORCID ID in publication: https://orcid.org/0000-0001-8319-7176
#   ORCID ID from "Biohub authors.xlsx" file: https://orcid.org/0000-0002-0734-9868
#
# Mismatched ORCID ID found for "Xu, Ke" in Pubmed 36116023
#   ORCID ID in publication: http://orcid.org/0000-0003-4444-0801
#   ORCID ID from "Biohub authors.xlsx" file: https://orcid.org/0000-0002-2788-194X
#
# Mismatched ORCID ID found for "Xu, Ke" in Pubmed 36000517
#   ORCID ID in publication: https://orcid.org/0000-0002-5361-6277
#   ORCID ID from "Biohub authors.xlsx" file: https://orcid.org/0000-0002-2788-194X
#
# Mismatched ORCID ID found for "Xu, Ke" in Pubmed 35848930
#   ORCID ID in publication: 0000-0003-4364-3770
#   ORCID ID from "Biohub authors.xlsx" file: https://orcid.org/0000-0002-2788-194X
#
# Mismatched ORCID ID found for "Xu, Ke" in Pubmed 35570744
#   ORCID ID in publication: 0000-0002-2453-4475
#   ORCID ID from "Biohub authors.xlsx" file: https://orcid.org/0000-0002-2788-194X
#
# Mismatched ORCID ID found for "Xu, Ke" in Pubmed 33165830
#   ORCID ID in publication: http://orcid.org/0000-0002-9969-3681
#   ORCID ID from "Biohub authors.xlsx" file: https://orcid.org/0000-0002-2788-194X
#
# ORCID ID found for "Pisco, Angela" in Pubmed 36050550 :
#  http://orcid.org/0000-0003-0142-2355
#
# ORCID ID found for "Palumbi, Steve" in Pubmed 36114282 :
#  0000-0001-5195-1947
#
# ORCID ID found for "Yu, Bin" in Pubmed 35933696 :
#  https://orcid.org/0000-0002-0397-6610
#
# Mismatched ORCID ID found for "Pollard, Katie" in Pubmed 36138165
#   ORCID ID in publication: 0000-0002-9870-6196
#   ORCID ID from "Biohub authors.xlsx" file: https://orcid.org/0000-0002-9870-6196
#
# Mismatched ORCID ID found for "Turnbaugh, Peter" in Pubmed 36138165
#   ORCID ID in publication: 0000-0002-0888-2875
#   ORCID ID from "Biohub authors.xlsx" file: https://orcid.org/0000-0002-0888-2875
#
# ORCID ID found for "Pisco, Angela" in Pubmed 36050550 :
#  http://orcid.org/0000-0003-0142-2355
#
# Mismatched ORCID ID found for "DeRisi, Joe" in Pubmed 36252253
#   ORCID ID in publication: 0000-0002-4611-9205
#   ORCID ID from "Biohub authors.xlsx" file: https://orcid.org/0000-0002-4611-9205
#
# Mismatched ORCID ID found for "Huang, KC" in Pubmed 36191183
#   ORCID ID in publication: 0000-0002-8043-8138
#   ORCID ID from "Biohub authors.xlsx" file: https://orcid.org/0000-0002-8043-8138
#
# Mismatched ORCID ID found for "Banfield, Jill" in Pubmed 36175428
#   ORCID ID in publication: http://orcid.org/0000-0001-8203-8771
#   ORCID ID from "Biohub authors.xlsx" file: https://orcid.org/0000-0001-8203-8771
#
# Mismatched ORCID ID found for "Bateup, Helen" in Pubmed 36171373
#   ORCID ID in publication: http://orcid.org/0000-0002-0135-0972
#   ORCID ID from "Biohub authors.xlsx" file: https://orcid.org/0000-0002-0135-0972
#
# Mismatched ORCID ID found for "Ye, Jimmie" in Pubmed 36171194
#   ORCID ID in publication: http://orcid.org/0000-0001-6560-3783
#   ORCID ID from "Biohub authors.xlsx" file: https://orcid.org/0000-0001-6560-3783
#
# Mismatched ORCID ID found for "Smolke, Christina" in Pubmed 36166456
#   ORCID ID in publication: 0000-0002-5449-8495
#   ORCID ID from "Biohub authors.xlsx" file: https://orcid.org/0000-0002-5449-8495
#
# ORCID ID found for "Gawad, Chuck" in Pubmed 36163278 :
#  http://orcid.org/0000-0002-4728-8203
#
# Mismatched ORCID ID found for "Kim, Peter" in Pubmed 36161911
#   ORCID ID in publication: 0000-0001-6503-4541
#   ORCID ID from "Biohub authors.xlsx" file: https://orcid.org/0000-0001-6503-4541
#
# Mismatched ORCID ID found for "Xu, Ke" in Pubmed 36153973
#   ORCID ID in publication: 0000-0002-2788-194X
#   ORCID ID from "Biohub authors.xlsx" file: https://orcid.org/0000-0002-2788-194X
#
# Mismatched ORCID ID found for "Pollard, Katie" in Pubmed 36138165
#   ORCID ID in publication: 0000-0002-9870-6196
#   ORCID ID from "Biohub authors.xlsx" file: https://orcid.org/0000-0002-9870-6196
#
# Mismatched ORCID ID found for "Turnbaugh, Peter" in Pubmed 36138165
#   ORCID ID in publication: 0000-0002-0888-2875
#   ORCID ID from "Biohub authors.xlsx" file: https://orcid.org/0000-0002-0888-2875
#
# ORCID ID found for "Blish, Catherine" in Pubmed 36137009 :
#  0000-0001-6946-7627
#
# ORCID ID found for "McCutcheon, Krista" in Pubmed 36126074 :
#  0000-0003-1942-5175
#
# ORCID ID found for "Wong, Joan" in Pubmed 36126074 :
#  0000-0002-7849-6320
#
# ORCID ID found for "Pak, John" in Pubmed 36126074 :
#  0000-0002-2998-9735
#
# Mismatched ORCID ID found for "Smolke, Christina" in Pubmed 36107884
#   ORCID ID in publication: 0000-0002-5449-8495
#   ORCID ID from "Biohub authors.xlsx" file: https://orcid.org/0000-0002-5449-8495
#
# Mismatched ORCID ID found for "Soh, Tom" in Pubmed 36097164
#   ORCID ID in publication: 0000-0001-9443-857X
#   ORCID ID from "Biohub authors.xlsx" file: https://orcid.org/0000-0001-9443-857X
#
# Mismatched ORCID ID found for "Kim, Peter" in Pubmed 36076082
#   ORCID ID in publication: http://orcid.org/0000-0001-6503-4541
#   ORCID ID from "Biohub authors.xlsx" file: https://orcid.org/0000-0001-6503-4541
#
# ORCID ID found for "Ott, Melanie" in Pubmed 36075902 :
#  0000-0002-5697-1274
#
# Mismatched ORCID ID found for "Puschnik, Andreas" in Pubmed 36074821
#   ORCID ID in publication: 0000-0002-9605-9458
#   ORCID ID from "Biohub authors.xlsx" file: https://orcid.org/0000-0002-9605-9458
#
# ORCID ID found for "Blish, Catherine" in Pubmed 36074821 :
#  0000-0001-6946-7627
#
# Mismatched ORCID ID found for "Huang, KC" in Pubmed 36069446
#   ORCID ID in publication: 0000-0002-8043-8138
#   ORCID ID from "Biohub authors.xlsx" file: https://orcid.org/0000-0002-8043-8138
#
# Mismatched ORCID ID found for "Huang, KC" in Pubmed 36067229
#   ORCID ID in publication: 0000-0002-8043-8138
#   ORCID ID from "Biohub authors.xlsx" file: https://orcid.org/0000-0002-8043-8138
#
# ORCID ID found for "Roybal, Kole" in Pubmed 36066491 :
#  0000-0003-3030-7954
#
# Mismatched ORCID ID found for "Fordyce, Polly" in Pubmed 36064771
#   ORCID ID in publication: 0000-0002-9505-0638
#   ORCID ID from "Biohub authors.xlsx" file: https://orcid.org/0000-0002-9505-0638
#
# ORCID ID found for "Pisco, Angela" in Pubmed 36050550 :
#  http://orcid.org/0000-0003-0142-2355
#
# Mismatched ORCID ID found for "Marson, Alex" in Pubmed 36002574
#   ORCID ID in publication: http://orcid.org/0000-0002-2734-5776
#   ORCID ID from "Biohub authors.xlsx" file: https://orcid.org/0000-0002-2734-5776
#
# Mismatched ORCID ID found for "Poon, Ada" in Pubmed 35995855
#   ORCID ID in publication: 0000-0003-2647-6069
#   ORCID ID from "Biohub authors.xlsx" file: https://orcid.org/0000-0003-2647-6069
#
# ORCID ID found for "Blish, Catherine" in Pubmed 35982307 :
#  http://orcid.org/0000-0001-6946-7627
#
# ORCID ID found for "Ott, Melanie" in Pubmed 35945353 :
#  0000-0001-8374-669X
#
# ORCID ID found for "Srivastava, Deepak" in Pubmed 35938400 :
#  0000-0002-3480-5953
#
# ORCID ID found for "Dumont, Sophie" in Pubmed 35880301 :
#  0000-0002-8283-1523
#
# Mismatched ORCID ID found for "Reiter, Jeremy" in Pubmed 35793002
#   ORCID ID in publication: 0000-0002-6512-320X
#   ORCID ID from "Biohub authors.xlsx" file: https://orcid.org/0000-0002-6512-320X
#
# Mismatched ORCID ID found for "Turnbaugh, Peter" in Pubmed 35668713
#   ORCID ID in publication: 0000-0002-0888-2875
#   ORCID ID from "Biohub authors.xlsx" file: https://orcid.org/0000-0002-0888-2875
#
# ORCID ID found for "Jerby-Arnon, Livnat" in Pubmed 35513526 :
#  http://orcid.org/0000-0002-4037-386X
#
# Mismatched ORCID ID found for "Yosef, Nir" in Pubmed 35449415
#   ORCID ID in publication: 0000-0001-9004-1225
#   ORCID ID from "Biohub authors.xlsx" file: https://orcid.org/0000-0001-9004-1225
#
# Fetch done.

# %%
#for day in range(1,5):
for day in [7,6,5,4,3,2,1]:
    start=(datetime.date.today() - datetime.timedelta(day+4)).strftime('%Y-%m-%d')
    end=(datetime.date.today() - datetime.timedelta(day)).strftime('%Y-%m-%d') 
    df=af.Bibliometrics_Collect(start,end)
    df.fillna('', inplace=True)
    df.to_csv('database/basedb.csv', mode='a', index=False,header=False, encoding='utf-8-sig')
    print('done.',start,':',end)
# Out:
# BioMedrxiv: Fetching search results 1 to 10...
# BioMedrxiv: Fetching search results 11 to 20...
# BioMedrxiv: Fetching search results 21 to 30...
# BioMedrxiv: Fetching search results 31 to 40...
# BioMedrxiv: Fetched 33 records in 136.2 seconds.
# Arxiv: Fetching search results 1 to 9...
# Arxiv: Fetched 7 records in 5.6 seconds.
# request url is: https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term=(zuckerb*[Affiliation] AND biohub[Affiliation]) OR "cz biohub"[Affiliation] OR "czi biohub"[Affiliation]&usehistory=y&datetype=pdat&mindate=2022/09/01&maxdate=2022/10/10
#   0%|          | 0/1 [00:00<?, ?it/s]
# request url is: https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&query_key=1&WebEnv=MCID_6352e08d0c4b8979d004bab0&retstart=0&retmax=2000&retmode=xml
# Pubmed: Fetched 70 records in 23.7 seconds.
# Fetch done.

# %%
base.columns

['record id', 'save datetime', 'biohub author', 'possible biohub author',
       'corresponding author', 'corresponding author institution', 'journal',
       'doi', 'pmid', 'title', 'url', 'abstract', 'keyword', 'pdf url',
       'version', 'version number', 'type', 'date', 'epost date',
       'publish date', 'authors', 'authors2', 'affiliations list',
       'author - affiliations', 'published or not', 'confirm published doi',
       'confirm preprint doi', 'possible match result', 'match id',
       'record change number']
# Out:
# Index(['record id', 'save datetime', 'biohub author', 'possible biohub author',
#        'corresponding author', 'corresponding author institution', 'journal',
#        'doi', 'pmid', 'title', 'url', 'abstract', 'keyword', 'pdf url',
#        'version', 'version number', 'type', 'date', 'epost date',
#        'publish date', 'authors', 'authors2', 'affiliations list',
#        'author - affiliations', 'published or not', 'confirm published doi',
#        'confirm preprint doi', 'possible match result', 'match id',
#        'record change number'],
#       dtype='object')

# %% [markdown]
# # 1. 试图用API收集biorxiv + medrixv
# 已经完成！ 整合进去了！BioMedrxiv_Search2

# %% [markdown]
# # 2. 原preprint的1加一个能发现biohub author & 所属地的
#
# 加到方法2里了！

# %%
df
# Out:
#    journal                    version                        doi  \
# 0  bioRxiv  biorxiv;2022.08.12.503709  10.1101/2022.08.12.503709
# 1  bioRxiv  biorxiv;2021.12.13.472243  10.1101/2021.12.13.472243
#
#                                                  url  \
# 0  http://www.biorxiv.org/content/10.1101/2022.08...
# 1  http://www.biorxiv.org/content/10.1101/2021.12...
#
#                                                title  \
# 0  Deep generative modeling of transcriptional dy...
# 1  An organism-wide atlas of hormonal signaling b...
#
#                                              authors corresponding author  \
# 0  Gayoso, A.; Weiler, P.; Lotfollahi, M.; Klein,...            Nir Yosef
# 1  Liu, S.; Ezran, C.; Wang, M. F. Z.; Li, Z.; Th...     James E. Ferrell
#
#                     corresponding author institution version number  \
# 0                 University of California, Berkeley              1
# 1  Department of Chemical and Systems Biology, St...              2
#
#           type  epost date                                           abstract  \
# 0  new results  01/15/2022  RNA velocity has been rapidly adopted to guide...
# 1  new results  01/14/2022  Hormones coordinate long-range cell-cell commu...
#
#   published or not published_doi save datetime  \
# 0               NA       No yet.    10/20/2022
# 1               NA       No yet.    10/20/2022
#
#                                          author list  \
# 0  Adam Gayoso; Philipp Weiler; Mohammad Lotfolla...
# 1  Shixuan Liu; Camille Ezran; Michael F. Z. Wang...
#
#                                    affiliations list  \
# 0  Center for Computational Biology, University o...
# 1  Department of Chemical and Systems Biology, St...
#
#                                author - affiliations  biohub author
# 0  [['Adam Gayoso', 'Center for Computational Bio...  Aaron Streets
# 1  [['Shixuan Liu', 'Department of Chemical and S...            NaN

# %%
print(df.columns)
# Out:
# Index(['journal', 'version', 'doi', 'url', 'title', 'authors',
#        'corresponding author', 'corresponding author institution',
#        'version number', 'type', 'epost date', 'abstract', 'published or not',
#        'published_doi', 'save datetime', 'author list', 'affiliations list',
#        'author - affiliations', 'biohub author'],
#       dtype='object')

# %% [markdown]
# # 试一下arxiv的api
# 看了。感觉还是不行。。

# %% [markdown]
# # 3. 改进pubmed的搜索词
# 好了！但是和bill再check下搜索方式有没有错。以及czi搜不到
# # 4. pubmed那边用api来搜索对应的preprint
# 改好了！
#
# Conversely, https://api.biorxiv.org/pubs/medrxiv/10.1371/journal.pone.0256482
# will output publication metadata for the medRxiv paper with published DOI 10.1371/journal.pone.0256482. 可以用preprint的doi找pub 也可以用pub的doi找对应的preprint。 但得定义好发表的位置
# 考虑一下加到pubmed那边？
# 'https://api.biorxiv.org/pubs/'+servel+'/'+doi

# %% [markdown]
# # 5.想把作者也合并进来
# 做好了！

# %%
df3.columns
# Out:
# Index(['title', 'epost date', 'publish date', 'pmid', 'abstract', 'doi',
#        'author list', 'journal', 'keyword', 'url', 'biohub author',
#        'corresponding author', 'corresponding author institution',
#        'affiliations list', 'author - affiliations', 'save datetime',
#        'confirm preprint doi'],
#       dtype='object')

# %%
df3
# Out:
#                                                 title  epost date  \
# 0   High Parental Vaccine Motivation at a Neighbor...  2021/12/13
# 1   ATXN10 Is Required for Embryonic Heart Develop...  2021/12/14
# 2   Mitral Valve Atlas for Artificial Intelligence...  2021/12/10
# 3   The impact of the COVID-19 preventive measures...  2021/12/10
# 4   Ciliary Hedgehog signaling patterns the digest...  2021/12/10
# 5   ZAF, the first open source fully automated fee...  2021/12/09
# 6   Exercise plasma boosts memory and dampens brai...  2021/12/08
# 7   Autism risk gene POGZ promotes chromatin acces...
# 8   Discovery of indole-modified aptamers for high...  2021/12/07
# 9   Viral evasion of the integrated stress respons...  2021/12/07
# 10  Reference phantom selection in pediatric compu...  2021/12/06
# 11  Millimeter-scale vertical partitioning of nitr...  2021/12/03
# 12  A multi-scale map of cell structure fusing pro...  2021/11/24
# 13  Synthetic biology: at the crossroads of geneti...  2021/11/16
# 14  Self-guarding of MORC3 enables virulence facto...  2021/11/10
# 15  Biosynthesis of triacsin featuring an N-hydrox...  2021/11/01
# 16  Anti-SARS-CoV-2 and Autoantibody Profiles in t...
# 17  Accelerated Electron Transfer in Nanostructure...  2021/10/19
# 18  Hydrogel-Based Slow Release of a Receptor-Bind...  2021/10/14
# 19    Single cell biology-a Keystone Symposia report.  2021/10/03
# 20  High throughput and quantitative enzymology in...  2021/09/27
# 21  Long-term MRI changes in a patient with Kelch-...
# 22  Human microglia states are conserved across ex...  2021/09/17
# 23                          The cell as a bag of RNA.  2021/08/27
# 24  MaxDIA enables library-based and library-free ...  2021/07/08
#
#       publish date      pmid  \
# 0    2022/1/13/6/0  35018317
# 1     2022/1/1/6/0  34970537
# 2   2021/12/28/6/0  34957251
# 3   2021/12/14/6/0  34902583
# 4   2021/12/12/6/0  34893605
# 5   2021/12/10/6/0  34882088
# 6   2021/12/10/6/0  34880498
# 7    2021/12/9/6/0  34879283
# 8    2021/12/9/6/0  34876561
# 9    2021/12/9/6/0  34876554
# 10   2021/12/7/6/0  34866159
# 11   2021/12/5/6/0  34862473
# 12  2021/11/26/6/0  34819669
# 13  2021/11/18/6/0  34786712
# 14  2021/11/12/6/0  34759314
# 15   2021/11/3/6/0  34725510
# 16  2021/10/26/6/0  34694339
# 17  2021/10/21/6/0  34668339
# 18  2021/10/16/6/0  34651342
# 19   2021/10/5/6/0  34605044
# 20   2021/10/1/6/0  34592682
# 21   2021/9/26/6/0  34561925
# 22   2021/9/19/6/0  34536354
# 23    2021/9/1/6/0  34462156
# 24   2021/7/10/6/0  34239088
#
#                                              abstract  \
# 0   Purpose: To understand vaccine attitudes of La...
# 1   Atxn10 is a gene known for its role in cytokin...
# 2   Severe mitral regurgitation (MR) is a cardiac ...
# 3   We quantify the impact of COVID-19-related con...
# 4   How tubular organs elongate is poorly understo...
# 5   In the past few decades, aquatic animals have ...
# 6   Physical exercise is generally beneficial to a...
# 7   Deleterious genetic variants in POGZ, which en...
# 8   Glycosylation is one of the most abundant form...
# 9   Viral infection triggers activation of the int...
# 10  Radiation dose metrics vary by the calibration...
# 11  Microbial mats are modern analogues of the fir...
# 12  The cell is a multi-scale structure with modul...
# 13  Synthetic biology has the potential to transfo...
# 14  Pathogens use virulence factors to inhibit the...
# 15  Triacsins are an intriguing class of specializ...
# 16  Neuropsychiatric manifestations of COVID-19 ha...
# 17  Electrochemical biosensors hold the exciting p...
# 18  The development of effective vaccines that can...
# 19  Single cell biology has the potential to eluci...
# 20  Accurate predictions from models based on phys...
# 21  The aim of this study was to identify the long...
# 22  Microglia are resident macrophages in the brai...
# 23  Genomic sequencing has provided insight into t...
# 24  MaxDIA is a software platform for analyzing da...
#
#                              doi  \
# 0          10.1089/heq.2021.0073
# 1      10.3389/fcell.2021.705182
# 2       10.3389/fcvm.2021.759675
# 3     10.1016/j.ijid.2021.12.323
# 4     10.1038/s41467-021-27319-z
# 5            10.7554/eLife.74234
# 6     10.1038/s41586-021-04183-x
# 7   10.1016/j.celrep.2021.110089
# 8     10.1038/s41467-021-26933-1
# 9     10.1038/s41467-021-26164-4
# 10    10.1007/s00247-021-05227-0
# 11    10.1038/s41396-021-01161-z
# 12    10.1038/s41586-021-04115-9
# 13            10.1111/nyas.14710
# 14    10.1038/s41586-021-04054-5
# 15    10.1038/s41589-021-00895-3
# 16  10.1001/jamaneurol.2021.3821
# 17        10.1002/advs.202102495
# 18        10.1002/adma.202104362
# 19            10.1111/nyas.14692
# 20     10.1016/j.sbi.2021.07.010
# 21             10.1111/ene.15120
# 22    10.1016/j.stem.2021.08.015
# 23     10.1016/j.tig.2021.08.003
# 24    10.1038/s41587-021-00968-7
#
#                                           author list  \
# 0   Jamie Naso ; Susy Rojas ; James Peng ; Carina ...
# 1   Melissa R Bentley-Ford ; Reagan S Andersen ; M...
# 2   Yaghoub Dabiri ; Jiang Yao ; Vaikom S Mahadeva...
# 3   Leon King Tran ; Dai-Wei Huang ; Nien-Kung Li ...
# 4   Ying Yang ; Pekka Paivinen ; Chang Xie ; Alexi...
# 5   Merlin Lange ; AhmetCan Solak ; Shruthi Vijay ...
# 6   Zurine De Miguel ; Nathalie Khoury ; Michael J...
# 7   Eirene Markenscoff-Papadimitriou ; Fadya Binya...
# 8   Alex M Yoshikawa ; Alexandra Rangel ; Trevor F...
# 9   Michael Schoof ; Lan Wang ; J Zachery Cogan ; ...
# 10  Philip W Chu ; Sophronia Yu ; Yifei Wang ; J A...
# 11  P Maza-Márquez ; M D Lee ; A M Detweiler ; B M...
# 12  Yue Qin ; Edward L Huttlin ; Casper F Winsnes ...
# 13  Jennifer Cable ; Joshua N Leonard ; Timothy K ...
# 14  Moritz M Gaidt ; Alyssa Morrow ; Marian R Fair...
# 15  Antonio Del Rio Flores ; Frederick F Twigg ; Y...
# 16  Christopher M Bartley ; Claire Johns ; Thomas ...
# 17  Kaiyu Fu ; Ji-Won Seo ; Vladimir Kesler ; Nico...
# 18  Emily C Gale ; Abigail E Powell ; Gillie A Rot...
# 19  Jennifer Cable ; Michael B Elowitz ; Ana I Dom...
# 20  D A Mokhtari ; M J Appel ; P M Fordyce ; D Her...
# 21  Hidehiro Ishikawa ; Caleigh Mandel-Brehm ; Aki...
# 22  Galina Popova ; Sarah S Soliman ; Chang N Kim ...
# 23                                    Stephen R Quake
# 24  Pavel Sinitcyn ; Hamid Hamzeiy ; Favio Salinas...
#
#                                               journal  \
# 0                                       Health equity
# 1         Frontiers in cell and developmental biology
# 2                Frontiers in cardiovascular medicine
# 3   International journal of infectious diseases :...
# 4                               Nature communications
# 5                                               eLife
# 6                                              Nature
# 7                                        Cell reports
# 8                               Nature communications
# 9                               Nature communications
# 10                                Pediatric radiology
# 11                                   The ISME journal
# 12                                             Nature
# 13         Annals of the New York Academy of Sciences
# 14                                             Nature
# 15                            Nature chemical biology
# 16                                     JAMA neurology
# 17  Advanced science (Weinheim, Baden-Wurttemberg,...
# 18         Advanced materials (Deerfield Beach, Fla.)
# 19         Annals of the New York Academy of Sciences
# 20              Current opinion in structural biology
# 21                      European journal of neurology
# 22                                     Cell stem cell
# 23                           Trends in genetics : TIG
# 24                               Nature biotechnology
#
#                                               keyword  \
# 0                     COVID-19 ; community ; vaccines
# 1   acinar-to-ductal metaplasia (ADM) ; ataxin 10 ...
# 2   MitraClip ; cardiac imaging ; finite element m...
# 3   COVID-19 ; case ; effective population size ; ...
# 4
# 5   aquatic ; automatic ; developmental biology ; ...
# 6
# 7
# 8
# 9
# 10  Children ; Computed tomography ; Phantom ; Rad...
# 11
# 12
# 13  CAR T cells ; CRISPR ; bacterial engineering ;...
# 14
# 15
# 16
# 17  aptamer ; biosensors ; electrochemical sensors...
# 18  COVID-19 ; SARS-CoV-2 ; adjuvants ; hydrogels ...
# 19  development ; differentiation ; lineage tracin...
# 20
# 21  Kelch-like protein 11 ; MRI ; paraneoplastic s...
# 22  double-stranded DNA breaks ; human microglia ;...
# 23
# 24
#
#                                          url  \
# 0   https://pubmed.ncbi.nlm.nih.gov/35018317
# 1   https://pubmed.ncbi.nlm.nih.gov/34970537
# 2   https://pubmed.ncbi.nlm.nih.gov/34957251
# 3   https://pubmed.ncbi.nlm.nih.gov/34902583
# 4   https://pubmed.ncbi.nlm.nih.gov/34893605
# 5   https://pubmed.ncbi.nlm.nih.gov/34882088
# 6   https://pubmed.ncbi.nlm.nih.gov/34880498
# 7   https://pubmed.ncbi.nlm.nih.gov/34879283
# 8   https://pubmed.ncbi.nlm.nih.gov/34876561
# 9   https://pubmed.ncbi.nlm.nih.gov/34876554
# 10  https://pubmed.ncbi.nlm.nih.gov/34866159
# 11  https://pubmed.ncbi.nlm.nih.gov/34862473
# 12  https://pubmed.ncbi.nlm.nih.gov/34819669
# 13  https://pubmed.ncbi.nlm.nih.gov/34786712
# 14  https://pubmed.ncbi.nlm.nih.gov/34759314
# 15  https://pubmed.ncbi.nlm.nih.gov/34725510
# 16  https://pubmed.ncbi.nlm.nih.gov/34694339
# 17  https://pubmed.ncbi.nlm.nih.gov/34668339
# 18  https://pubmed.ncbi.nlm.nih.gov/34651342
# 19  https://pubmed.ncbi.nlm.nih.gov/34605044
# 20  https://pubmed.ncbi.nlm.nih.gov/34592682
# 21  https://pubmed.ncbi.nlm.nih.gov/34561925
# 22  https://pubmed.ncbi.nlm.nih.gov/34536354
# 23  https://pubmed.ncbi.nlm.nih.gov/34462156
# 24  https://pubmed.ncbi.nlm.nih.gov/34239088
#
#                                         biohub author  \
# 0                                       Joseph DeRisi
# 1                                     Jeremy F Reiter
# 2                                        Rima Arnaout
# 3                                           Lucy M Li
# 4                                     Jeremy F Reiter
# 5   Merlin LangeAhmetCan SolakShruthi Vijay KumarH...
# 6                          Lichao ZhangJoshua E Elias
# 7                                 Katherine S Pollard
# 8                                           H Tom Soh
# 9                                          Adam Frost
# 10                                       Sophronia Yu
# 11                                      A M Detweiler
# 12                                      Emma Lundberg
# 13                                      Kole T Roybal
# 14                                          Nir Yosef
# 15                                       Wenjun Zhang
# 16                                    Joseph L DeRisi
# 17                                          H Tom Soh
# 18                                        Peter S Kim
# 19                       Aaron StreetsStephen R Quake
# 20                                        P M Fordyce
# 21                      Sabrina A MannJoseph L DeRisi
# 22  Bryant B ChhunZev J GartnerShalin B MehtaTomas...
# 23                                    Stephen R Quake
# 24                        Daniel ItzhakFrank McCarthy
#
#                                  corresponding author  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3            Lucy M LiJulia A PalaciosHsiao-Han Chang
# 4                                     Jeremy F Reiter
# 5                                                 NaN
# 6                                     Tony Wyss-Coray
# 7   Eirene Markenscoff-PapadimitriouJohn L Rubenstein
# 8                                           H Tom Soh
# 9                                        Peter Walter
# 10                              Rebecca Smith-Bindman
# 11                                     P Maza-Márquez
# 12                           Emma LundbergTrey Ideker
# 13                                                NaN
# 14                      Moritz M GaidtRussell E Vance
# 15                                       Wenjun Zhang
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                             P M FordyceD Herschlag
# 21                                                NaN
# 22                                Tomasz J Nowakowski
# 23                                    Stephen R Quake
# 24                                         Jürgen Cox
#
#                      corresponding author institution  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3   Chan Zuckerberg Biohub, San Francisco, CA, USA...
# 4   Department of Biochemistry and Biophysics, Car...
# 5                                                 NaN
# 6   Department of Neurology and Neurological Scien...
# 7   Department of Psychiatry, Langley Porter Psych...
# 8   Department of Radiology, Stanford University, ...
# 9   Howard Hughes Medical Institute, University of...
# 10  Department of Epidemiology & Biostatistics, Un...
# 11  Exobiology Branch, NASA Ames Research Center, ...
# 12  Science for Life Laboratory, School of Enginee...
# 13                                                NaN
# 14  Division of Immunology and Pathogenesis, Depar...
# 15  Department of Chemical and Biomolecular Engine...
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20  Department of Bioengineering, Stanford Univers...
# 21                                                NaN
# 22  Department of Anatomy, University of Californi...
# 23  Stanford University and Chan Zuckerberg Biohub...
# 24  Computational Systems Biochemistry Research Gr...
#
#                                     affiliations list  \
# 0   Chan Zuckerberg Biohub, San Francisco, Califor...
# 1   Department of Biochemistry and Biophysics, Uni...
# 2   3DT Holdings LLC, San Diego, CA, United States...
# 3   Chan Zuckerberg Biohub, San Francisco, CA, USA...
# 4   Department of Biochemistry and Biophysics, Car...
# 5   Chan Zuckerberg Biohub, San Francisco, United ...
# 6   Behavioral and Functional Neuroscience Laborat...
# 7   Department of Psychiatry, Langley Porter Psych...
# 8   Department of Bioengineering, Stanford Univers...
# 9   Department of Biochemistry and Biophysics, Uni...
# 10  Chan Zuckerberg Biohub, San Francisco, CA, USA...
# 11  Exobiology Branch, NASA Ames Research Center, ...
# 12  Bioinformatics and Systems Biology Program, Un...
# 13  A2 Biotherapeutics, Agoura Hills, California.;...
# 14  Division of Genetics, Genomics and Development...
# 15  Department of Chemical and Biomolecular Engine...
# 16  Department of Biochemistry and Biophysics, Uni...
# 17  Department of Chemical Engineering, Stanford U...
# 18  Department of Biochemistry, Stanford Universit...
# 19  Berlin Institute for Medical Systems Biology, ...
# 20  Department of Biochemistry, Stanford Universit...
# 21  Department of Biochemistry and Biophysics, Uni...
# 22  Chan Zuckerberg Biohub, San Francisco, CA, USA...
# 23  Stanford University and Chan Zuckerberg Biohub...
# 24  Bruker Daltonik, GmbH, Bremen, Germany.;Chan Z...
#
#                                 author - affiliations save datetime  \
# 0   Jamie Naso: Unidos en Salud, San Francisco, Ca...    10/20/2022
# 1   Melissa R Bentley-Ford: Department of Cell, De...    10/20/2022
# 2   Yaghoub Dabiri: 3DT Holdings LLC, San Diego, C...    10/20/2022
# 3   Leon King Tran: Department of Statistics, Stan...    10/20/2022
# 4   Ying Yang: Department of Biochemistry and Biop...    10/20/2022
# 5   Merlin Lange: Chan Zuckerberg Biohub, San Fran...    10/20/2022
# 6   Zurine De Miguel: Department of Neurology and ...    10/20/2022
# 7   Eirene Markenscoff-Papadimitriou: Department o...    10/20/2022
# 8   Alex M Yoshikawa: Department of Chemical Engin...    10/20/2022
# 9   Michael Schoof: Howard Hughes Medical Institut...    10/20/2022
# 10  Philip W Chu: Department of Epidemiology & Bio...    10/20/2022
# 11  P Maza-Márquez: Exobiology Branch, NASA Ames R...    10/20/2022
# 12  Yue Qin: Department of Medicine, University of...    10/20/2022
# 13  Jennifer Cable: PhD Science Writer, New York, ...    10/20/2022
# 14  Moritz M Gaidt: Division of Immunology and Pat...    10/20/2022
# 15  Antonio Del Rio Flores: Department of Chemical...    10/20/2022
# 16  Christopher M Bartley: Hanna H. Gray Fellow, H...    10/20/2022
# 17  Kaiyu Fu: Department of Electrical Engineering...    10/20/2022
# 18  Emily C Gale: Department of Biochemistry, Stan...    10/20/2022
# 19  Jennifer Cable: PhD Science Writer, New York, ...    10/20/2022
# 20  D A Mokhtari: Department of Biochemistry, Stan...    10/20/2022
# 21  Hidehiro Ishikawa: Department of Neurology, Mi...    10/20/2022
# 22  Galina Popova: Department of Anatomy, Universi...    10/20/2022
# 23  Stephen R Quake: Stanford University and Chan ...    10/20/2022
# 24  Pavel Sinitcyn: Computational Systems Biochemi...    10/20/2022
#
#            confirm preprint doi
# 0   10.1101/2021.07.30.21261274
# 1     10.1101/2021.04.29.441883
# 2                           NaN
# 3   10.1101/2021.06.08.21258434
# 4                           NaN
# 5     10.1101/2021.04.28.441879
# 6                           NaN
# 7     10.1101/2021.04.07.438852
# 8     10.1101/2021.03.13.435263
# 9     10.1101/2021.06.07.447473
# 10                          NaN
# 11                          NaN
# 12    10.1101/2020.06.21.163709
# 13                          NaN
# 14                          NaN
# 15    10.1101/2021.05.12.443849
# 16                          NaN
# 17    10.1101/2021.04.13.439686
# 18    10.1101/2021.03.31.437792
# 19                          NaN
# 20                          NaN
# 21                          NaN
# 22                          NaN
# 23                          NaN
# 24                          NaN

# %% [markdown]
# # 6. 把function 4 （above all) debug下

# %%
df.columns
# Out:
# Index(['journal', 'version', 'doi', 'url', 'title', 'authors',
#        'corresponding author', 'corresponding author institution',
#        'version number', 'type', 'epost date', 'abstract', 'published or not',
#        'published_doi', 'save datetime', 'author list', 'affiliations list',
#        'author - affiliations', 'biohub author', 'pdf url', 'publish date',
#        'PMID', 'keyword', 'confirm preprint doi'],
#       dtype='object')

# %%
df.head(5)
# Out:
#    journal                    version                        doi  \
# 0  bioRxiv  biorxiv;2022.05.13.491573  10.1101/2022.05.13.491573
# 1  bioRxiv  biorxiv;2022.05.12.491656  10.1101/2022.05.12.491656
# 2  bioRxiv  biorxiv;2022.05.11.490523  10.1101/2022.05.11.490523
# 3  bioRxiv  biorxiv;2022.04.28.489942  10.1101/2022.04.28.489942
# 4  bioRxiv  biorxiv;2022.05.10.491266  10.1101/2022.05.10.491266
#
#                                                  url  \
# 0  http://www.biorxiv.org/content/10.1101/2022.05...
# 1  http://www.biorxiv.org/content/10.1101/2022.05...
# 2  http://www.biorxiv.org/content/10.1101/2022.05...
# 3  http://www.biorxiv.org/content/10.1101/2022.04...
# 4  http://www.biorxiv.org/content/10.1101/2022.05...
#
#                                                title  \
# 0  Quantifying the adaptive landscape of commensa...
# 1  Astrocytic Gi-GPCR activation enhances stimulu...
# 2  Fermented foods restructure gut microbiota and...
# 3  Immediate myeloid depot for SARS-CoV-2 in the ...
# 4  Activated interstitial macrophages are a predo...
#
#                                              authors corresponding author  \
# 0                     Wong, D. P. G. H.; Good, B. H.      Benjamin H Good
# 1  Poskanzer, K.; Vaidyanathan, T. V.; Tse, V.; L...      Kira  Poskanzer
# 2  Spencer, S. P.; Lemus Silva, E. G.; Caffrey, E...  Justin L Sonnenburg
# 3  Magnen, M.; You, R.; Rao, A. A.; Davis, R. T.;...        Mark R Looney
# 4  Wu, T. T.-H.; Travaglini, K. J.; Rustagi, A.; ...      Mark A. Krasnow
#
#                     corresponding author institution version number  \
# 0                                Stanford University              1
# 1            University of California, San Francisco              1
# 2                                Stanford University              1
# 3                                               UCSF              2
# 4  Department of Biochemistry, Stanford Universit...              1
#
#           type  ... save datetime  \
# 0  new results  ...    10/20/2022
# 1  new results  ...    10/20/2022
# 2  new results  ...    10/20/2022
# 3  new results  ...    10/20/2022
# 4  new results  ...    10/20/2022
#
#                                          author list  \
# 0               Daniel P.G.H. Wong; Benjamin H. Good
# 1  Trisha V. Vaidyanathan; Vincent Tse; Esther M....
# 2  Sean Paul Spencer; Evelyn Giselle Lemus Silva;...
# 3  Mélia Magnen; Ran You; Arjun A. Rao; Ryan T. D...
# 4  Timothy Ting-Hsuan Wu; Kyle J. Travaglini; Arj...
#
#                                    affiliations list  \
# 0  Department of Applied Physics, Stanford Univer...
# 1  Neuroscience Graduate Program, University of C...
# 2  Department of Microbiology and Immunology, Sta...
# 3  Department of Medicine, University of Californ...
# 4  Department of Biochemistry, Stanford Universit...
#
#                                author - affiliations            biohub author  \
# 0  [['Daniel P.G.H. Wong', 'Department of Applied...         Benjamin H. Good
# 1  [['Trisha V. Vaidyanathan', 'Neuroscience Grad...        Kira E. Poskanzer
# 2  [['Sean Paul Spencer', 'Department of Microbio...  Justin Laine Sonnenburg
# 3  [['Mélia Magnen', 'Department of Medicine, Uni...     Charles R. Langelier
# 4  [['Timothy Ting-Hsuan Wu', 'Department of Bioc...       Catherine A. Blish
#
#   pdf url publish date PMID keyword confirm preprint doi
# 0     NaN          NaN  NaN     NaN                  NaN
# 1     NaN          NaN  NaN     NaN                  NaN
# 2     NaN          NaN  NaN     NaN                  NaN
# 3     NaN          NaN  NaN     NaN                  NaN
# 4     NaN          NaN  NaN     NaN                  NaN
#
# [5 rows x 24 columns]

# %% [markdown]
# # 6. 先确保网站能看！！！GH Action不报错！
# 大概好了！
# 等后面的搞完再次debug下

# %%
base.columns
['record id', 'save datetime', 'biohub author', 'possible biohub author',
       'corresponding author', 'corresponding author institution', 'journal',
       'doi', 'pmid', 'title', 'url', 'abstract', 'keyword', 'pdf url',
       'version', 'version number', 'type', 'date', 'epost date',
       'publish date', 'authors', 'authors2', 'affiliations list',
       'author - affiliations', 'published or not', 'confirm published doi',
       'confirm preprint doi', 'possible match result', 'match id',
       'record change number']
# Out:
# Index(['record id', 'save datetime', 'biohub author', 'possible biohub author',
#        'corresponding author', 'corresponding author institution', 'journal',
#        'doi', 'pmid', 'title', 'url', 'abstract', 'keyword', 'pdf url',
#        'version', 'version number', 'type', 'date', 'epost date',
#        'publish date', 'authors', 'authors2', 'affiliations list',
#        'author - affiliations', 'published or not', 'confirm published doi',
#        'confirm preprint doi', 'possible match result', 'match id',
#        'record change number'],
#       dtype='object')

# %% [markdown]
# # 7. 用bill的来match author
#
# nickname middle lastname  #3 NN-NMI
#  加一下如果有两个middle name且比较长

# %% [markdown]
# ## 1. 版本1. 只适用于pubmed。 -> 可以改成从指定的index开始循环

# %%
def authormatch_pub(df):
    authors=pd.read_csv('database/pubmed api author.csv', encoding='utf-8-sig')
 
    # get Biohub author names/data

    def ORCID_format (orcid):
        try:
            find_orcid = re.search (r"([0-9]{4})-?([0-9]{4})-?([0-9]{4})-?([0-9]{3}[0-9X])", orcid)
        except:
            find_orcid = False
        if find_orcid:
            formatted_orcid = "https://orcid.org/"+find_orcid.group(1)+"-"+find_orcid.group(2)+"-"+find_orcid.group(3)+"-"+find_orcid.group(4)
        else:
            formatted_orcid = "nan"
        return (formatted_orcid)

    def strip_accents(text):
        try:
            text = unicode(text, 'utf-8')
        except NameError: # unicode is a default on python 3 
            pass

        text = unicodedata.normalize('NFD', text)\
            .encode('ascii', 'ignore')\
            .decode("utf-8")

        return (str(text))

    def text_field_set_null_to_blank (text): 
        if isinstance(text,str):
            return (text)
        else:
            return ("")
        

    condition = set() # for scoring Biohub authors

    Email_address_found = set()

    BiohubAuthors_df = pd.read_excel('database/Biohub authors.xlsx',
                                    dtype = { 
                                        'Middle' : str,
                                        'ORCID' : str,
                                        'Cohort' : str,
                                        'Email-Preferred' : str,
                                        'Email 2' : str},
                                    converters = { 
                                        'Ambiguous initials' : lambda x: np.where(x == True, True, False),
                                        'Ambiguous incomplete full' : lambda x: np.where(x == True, True, False),
                                    })

    BiohubAuthors_df['ORCID'] = BiohubAuthors_df['ORCID'].apply(ORCID_format)

    BiohubAuthors_df['MatchName'] = BiohubAuthors_df['MatchName'].apply(strip_accents)
    BiohubAuthors_df['Last Name'] = BiohubAuthors_df['Last Name'].apply(strip_accents)
    BiohubAuthors_df['First Name'] = BiohubAuthors_df['First Name'].apply(strip_accents)
    BiohubAuthors_df['Nickname'] = BiohubAuthors_df['Nickname'].apply(strip_accents)

    BiohubAuthors_df['Email 2'] = BiohubAuthors_df['Email 2'].apply(text_field_set_null_to_blank)

    BiohubAuthors_df['Length of award'] = BiohubAuthors_df['Length of award'].fillna(0).astype(int)

    BiohubAuthors_df['Award start date'] = BiohubAuthors_df['Award start date'].dt.date
    BiohubAuthors_df['Award end date'] = BiohubAuthors_df['Award end date'].dt.date

    BiohubAuthors_list = BiohubAuthors_df.values.tolist()
    BiohubAuthors_columns = BiohubAuthors_df.columns.tolist()


    List_MatchNames = BiohubAuthors_df['MatchName'].unique().tolist()
    biohub_authors = {} # column names are indexed in BiohubAuthors_columns.index("column name")
    biohub_authors_ORCID = {}
    biohub_authors_email = {}
    biohub_authors_variations = {} 
    biohub_authors_awarddates = {}

    name_match_weight = {
        "FN-NMI" : 3, # "FN-NMI" : first name-no middle initial
        "NN-NMI" : 3, # "NN-NMI" : Nickname-no middle initial
        "FN-MN" : 3,  # "FN-MN" : first name-middle name
        "FI-MN" : 3,  # "FI-MN" : first initial-middle name-(when preferred)
        "FN-MI" : 3,  # "FN-MI" : first name-middle initial
        "FN" : 2,     # "FN" : first name, omitting middle initial
        "NN" : 2,     # "NN" : Nickname-omitting middle initial
        "FI-MI" : 1,  # "FI-MI" : first initial-middle initial
        "FI-NMI" : 1, # "FI-NMI" : first initial-no middle initial
        "FI" : 0      # "FI" : first initial-omitting middle initial
    }

    for i in range (len(BiohubAuthors_df)):
        if not BiohubAuthors_df.loc[i]['MatchName'] in biohub_authors_awarddates:
            biohub_authors_awarddates[BiohubAuthors_df.loc[i]['MatchName']] = []
            if  BiohubAuthors_df.loc[i]['Award start date'] ==  BiohubAuthors_df.loc[i]['Award start date']: # check for null
                biohub_authors_awarddates[BiohubAuthors_df.loc[i]['MatchName']].append(BiohubAuthors_df.loc[i]['Award start date'])
                biohub_authors_awarddates[BiohubAuthors_df.loc[i]['MatchName']].append(BiohubAuthors_df.loc[i]['Award end date'])
            else:
                biohub_authors_awarddates[BiohubAuthors_df.loc[i]['MatchName']].append(datetime.date(2000, 1, 1))
                biohub_authors_awarddates[BiohubAuthors_df.loc[i]['MatchName']].append(datetime.date(3000, 1, 1))


    for row in BiohubAuthors_list:
        MatchName = row[BiohubAuthors_columns.index("MatchName")]
        biohub_authors[MatchName] = row
            
        LastName = row[BiohubAuthors_columns.index("Last Name")].lower()
        FirstName = row[BiohubAuthors_columns.index("First Name")].lower()
        find_bracket = FirstName.find("[") # brackets used to indicate use of first initial as alternate to first name: "J[ames]"
        if find_bracket != -1:
            FirstName = FirstName.replace("[","").replace("]","")
        Nickname = row[BiohubAuthors_columns.index("Nickname")].lower()
        Middle = row[BiohubAuthors_columns.index("Middle")].lower()

        EntryName = LastName+", "+FirstName
        EntryFI = LastName+", "+FirstName[0:1]
        if Middle == "nmi":
            biohub_authors_variations[EntryName] = [MatchName, "FN-NMI"] # first name-no middle initial
            biohub_authors_variations[EntryFI] = [MatchName, "FI-NMI"] # first initial-no middle initial
            if Nickname != FirstName:
                EntryName = LastName+", "+Nickname
                biohub_authors_variations[EntryName] = [MatchName, "NN-NMI"] # Nickname-no middle initial
        else:
            biohub_authors_variations[EntryName] = [MatchName, "FN"] # first name, omitting middle initial
            biohub_authors_variations[EntryFI] = [MatchName, "FI"] # first initial-omitting middle initial
            if Nickname != FirstName:
                EntryName = LastName+", "+Nickname
                biohub_authors_variations[EntryName] = [MatchName, "NN"] # Nickname-omitting middle initial
            if len(Middle) > 1:
                EntryName = LastName+", "+FirstName+" "+Middle
                biohub_authors_variations[EntryName] = [MatchName, "FN-MN"] # first name-middle name
            if find_bracket != -1: 
                EntryName = EntryFI+" "+Middle
                biohub_authors_variations[EntryName] = [MatchName, "FI-MN"] # first initial-middle name-preferred
            EntryName = LastName+", "+FirstName+" "+Middle[0:1]
            biohub_authors_variations[EntryName] = [MatchName, "FN-MI"] # first name-middle initial
            EntryName = EntryFI+" "+Middle[0:1]
            if EntryName not in biohub_authors_variations:
                biohub_authors_variations[EntryName] = [MatchName, "FI-MI"] # first initial-middle initial
        
        email_list = re.findall (r"[a-zA-Z][a-zA-Z0-9_.-]*@[a-zA-Z][a-zA-Z0-9_.-]*", row[BiohubAuthors_columns.index("Email-Preferred")]+" "+row[BiohubAuthors_columns.index("Email 2")])
        for item in email_list:
            item = item.lower()
            biohub_authors_email[item] = row[BiohubAuthors_columns.index("MatchName")]
            
        if row[BiohubAuthors_columns.index("ORCID")] != 'nan':
            biohub_authors_ORCID[row[BiohubAuthors_columns.index("ORCID")]] = row[BiohubAuthors_columns.index("MatchName")]

    biohub_authors_variations_full = {} # includes compressed versions of names, omitting spaces, dashes, apostrophes, etc   

    for key,value in biohub_authors_variations.items():
        biohub_authors_variations_full[key] = value
        compress = key.replace(" ","").replace("-","").replace("\'","").replace(",",", ")
        if key[-2:-1] == " " and key[-3:-2] != ",":
            compress = compress[:-1]+key[-2:] # restore the penultimate space if there is one
        if compress != key:
            biohub_authors_variations_full[compress] = value


    # author_fields notes:
    #    "ForeName" includes middle initials
    #    "Initials" includes first name initial
    #    "Email" field may include email addresses for all authors with listed email addresses, not just the current author
    #    "BiohubAuthor" = "investigator", "intramural" (group/platform leader, etc)
    #    "MatchName" = uniform version of matched name for investigator or group leader, used for joining tables
    #    "MatchType" = Abbreviations for first name, first initial, NMI, etc. in biohub_authors_variations_full
    #    "TrustMatch" = Yes, Maybe, No - based on MatchType (if match based on initials) and if there are matching
    #                   or mis-matching ORCID IDs, email addresses, or campus affiliations
    #    "OrcidMatch" = True if record ORCID matches with Biohub author ORCID; False only if there are values for both that don't match
    #    "EmailMatch" = True if record email matches with Biohub author email
    #                       - ignore if there is a mis-match: Affiliation records for an author occasionally include 
    #                         email addresses for co-authors
    #    "AffiliationMatch" = True if record Affiliation includes a match to Biohub author campus affiliation
    #    "Biohub" -> "Chan Zuckerberg Biohub" or variants found in affiliation or email address
    #    "Biohub-Funding" -> "Chan Zuckerberg Biohub" or variants found in grant list
    authors.drop_duplicates(subset=authors.columns[0:10],inplace=True)
    author_fields = ['AuthorNo', 'pmid', 'name', 'ORCID', 'LastName', 'ForeName', 'Initials',
                    'affiliation', 'ISEmail', 'ISBiohub author','Suffix',
                    'BiohubAuthor',
                    'MatchName',
                    'TrustMatch', 
                    'MatchType',
                    'OrcidMatch',
                    'EmailMatch',
                    'AffiliationMatch',
                    'Biohub', 
                    'Biohub-Funding', 
                    'Stanford',
                    'UCSF',
                    'Berkeley',
                    'Email',  
                    'EqualContrib']

    for col in author_fields:
        if col not in authors.columns.to_list():
            authors[col]=''
    authors = authors[author_fields]
    authors.fillna('', inplace=True)


    # score for Biohub authorship

    for i in range(len(authors)):
        Name = strip_accents(authors.loc[i,"LastName"].lower()+", "+authors.loc[i,"ForeName"].lower())
        MatchName = ""
        MatchType = ""
        if Name in biohub_authors_variations_full:
            MatchName = biohub_authors_variations_full[Name][0]
            MatchType = biohub_authors_variations_full[Name][1] 
        else:
            compress = Name.replace(" ","").replace("-","").replace("\'","").replace(",",", ")
            if Name[-2:-1] == " " and Name[-3:-2] != ",":
                compress = compress[:-1]+Name[-2:] # restore the penultimate space if there is one
            if compress != Name and compress in biohub_authors_variations_full:
                MatchName = biohub_authors_variations_full[compress][0]
                MatchType = biohub_authors_variations_full[compress][1] 
            elif len(authors.loc[i,'ForeName'])>=2:
                if authors.loc[i,'ForeName'][-2] != " " and authors.loc[i,'ForeName'].find(" ") != -1:
                    # if the full middle name is given in the Pubmed record, which may not be present in the Biohub author record
                    forename = authors.loc[i,'ForeName'][:authors.loc[i,'ForeName'].find(" ")+2]
                    Name2 = strip_accents(authors.loc[i,'LastName'].lower()+", "+forename.lower())
                    if Name2 in biohub_authors_variations_full:
                        MatchName = biohub_authors_variations_full[Name2][0]
                        MatchType = biohub_authors_variations_full[Name2][1] 
                        print ("Found full middle name for Biohub author",Name,"PMID",authors.loc[i,'pmid'])
                    else:
                        compress = Name2.replace(" ","").replace("-","").replace("\'","").replace(",",", ")
                        if Name2[-2:-1] == " " and Name[-3:-2] != ",":
                            compress = compress[:-1]+Name[-2:] # restore the penultimate space if there is one
                        if compress != Name2:
                            if compress in biohub_authors_variations_full:
                                MatchName = biohub_authors_variations_full[compress][0]
                                MatchType = biohub_authors_variations_full[compress][1] 
                                print ("Found full middle name for Biohub author",Name,"PMID",authors.loc[i,'pmid'])
                    
                # ToDo - backup if there wasn't a match of the author name: 
                # else: 
                #       if the author record has an ORCID ID, try searching for it in the Biohub Author ORCID ID dictionary
                #       and alert user if there is a match; ditto if there is an email address
                
        if MatchName != "":
            authors.loc[i,'MatchName'] = MatchName
            authors.loc[i,"MatchType"] = MatchType
            authors.loc[i,"BiohubAuthor"] = biohub_authors[MatchName][BiohubAuthors_columns.index("Role")]
            authors.loc[i,"AffiliationMatch"] =  authors.iloc[i,author_fields.index(biohub_authors[MatchName][BiohubAuthors_columns.index("Campus (simple)")])]
            if authors.loc[i,"AffiliationMatch"] != True:
                if len(authors.loc[i,"BiohubAuthor"]) > 0:
                    if authors.loc[i,"Biohub"] == True:
                        authors.loc[i,"AffiliationMatch"] = True 
            orcid_from_record = authors.loc[i,"ORCID"]
            orcid_from_biohub_authors = biohub_authors[MatchName][BiohubAuthors_columns.index("ORCID")]
            if orcid_from_record == orcid_from_biohub_authors:
                authors.loc[i,"OrcidMatch"] = True
            elif len(orcid_from_record) > 0:
                if orcid_from_biohub_authors == "nan":
                    print ("ORCID ID found for \""+MatchName+"\" in Pubmed",authors.loc[i,'pmid'],":\n",orcid_from_record,"\n")
                else:
                    authors.loc[i,"OrcidMatch"] = False
                    print ("Mismatched ORCID ID found for \""+MatchName+"\" in Pubmed",authors.loc[i,'pmid'],"\n  ORCID ID in publication:",orcid_from_record,"\n  ORCID ID from \"Biohub authors.xlsx\" file:",orcid_from_biohub_authors,"\n")
            if str(authors.loc[i,'pmid'])+" "+authors.loc[i,'MatchName'] in Email_address_found:
                authors.loc[i,'EmailMatch'] = True
            
            # set TrustMatch:
            if authors.loc[i,"OrcidMatch"] or authors.loc[i,'EmailMatch'] or authors.loc[i,"Biohub"]:
                authors.loc[i,"TrustMatch"] = "Yes"
                condition.add(1)
            elif authors.loc[i,"AffiliationMatch"] and name_match_weight[MatchType] >= 2:
                authors.loc[i,"TrustMatch"] = "Yes"
                condition.add(2)
            elif authors.loc[i,"AffiliationMatch"] != True and name_match_weight[MatchType] >= 2:
                if biohub_authors[MatchName][BiohubAuthors_columns.index("Ambiguous incomplete full")] == True and name_match_weight[MatchType] == 2:
                    authors.loc[i,'TrustMatch'] = "Maybe"
                    condition.add(3)
                else:
                    authors.loc[i,'TrustMatch'] = "Yes"
                    condition.add(4)
            elif authors.loc[i,'AffiliationMatch'] and name_match_weight[MatchType] == 1 and biohub_authors[MatchName][BiohubAuthors_columns.index("Ambiguous initials")] == False:
                authors.loc[i,'TrustMatch'] = "Yes"
                condition.add(5)
            elif authors.loc[i,'AffiliationMatch'] and name_match_weight[MatchType] == 0 and biohub_authors[MatchName][BiohubAuthors_columns.index("Ambiguous initials")] == False:
                authors.loc[i,'TrustMatch'] = "Maybe"
                condition.add(6)
                
            elif authors.loc[i,'AffiliationMatch'] and name_match_weight[MatchType] == 1 and biohub_authors[MatchName][BiohubAuthors_columns.index("Ambiguous initials")] == True:
                authors.loc[i,'TrustMatch'] = "Maybe"
                condition.add(7)
            elif authors.loc[i,'AffiliationMatch'] and name_match_weight[MatchType] == 0 and biohub_authors[MatchName][BiohubAuthors_columns.index("Ambiguous initials")] == True:
                authors.loc[i,'TrustMatch'] = "No"
                condition.add(8)
                
            elif authors.loc[i,'AffiliationMatch'] != True and name_match_weight[MatchType] == 1 and biohub_authors[MatchName][BiohubAuthors_columns.index("Ambiguous initials")] == False:
                authors.loc[i,'TrustMatch'] = "Maybe"
                condition.add(9)
            elif authors.loc[i,'AffiliationMatch'] != True and name_match_weight[MatchType] == 0 and biohub_authors[MatchName][BiohubAuthors_columns.index("Ambiguous initials")] == False:
                authors.loc[i,'TrustMatch'] = "No"
                condition.add(10)
            elif authors.loc[i,'AffiliationMatch'] != True and name_match_weight[MatchType] <= 1 and biohub_authors[MatchName][BiohubAuthors_columns.index("Ambiguous initials")] == True:
                authors.loc[i,'TrustMatch'] = "No"
                condition.add(11)
            else:
                print ("TrustMatch error - didn't match any conditions, Author-PMID",Name,authors[i][author_fields.index("PMID")])
                print (authors.loc[i,'AffiliationMatch'],name_match_weight[MatchType], biohub_authors[MatchName][BiohubAuthors_columns.index("Ambiguous initials")])

            # Suffix match - 
            # for now, no Biohub authors have a suffix; when one does, we'll have to create a field for it; for now:
            
            if len(authors.loc[i,'Suffix'])>0:
                authors.loc[i,'TrustMatch'] = "No"

    authors.to_csv('database/pubmed api author.csv',index=False, encoding='utf-8-sig')		    
    
    
    # save them to dataframe.
    for ind,i in enumerate(authors['pmid']):
        if authors.loc[ind,'TrustMatch']=='Yes':
            if authors.loc[ind,'MatchName'] not in df.loc[df[df['pmid']==authors.loc[ind,'pmid']].index,'biohub author'].str.lower().replace(', ',' '):
                df.loc[df[df['pmid']==authors.loc[ind,'pmid']].index,'biohub author'] += authors.loc[ind,'MatchName']
        elif authors.loc[ind,'TrustMatch']=='Maybe':
            df.loc[df[df['pmid']==authors.loc[ind,'pmid']].index,'possible biohub author'] += authors.loc[ind,'MatchName']
    
    return df

authormatch_pub(df)
# Out:
# ORCID ID found for "Gawad, Chuck" in Pubmed 36163278 :
#  https://orcid.org/0000-0002-4728-8203
#
# ORCID ID found for "Blish, Catherine" in Pubmed 36074821 :
#  https://orcid.org/0000-0001-6946-7627
#
# ORCID ID found for "Pisco, Angela" in Pubmed 36050550 :
#  https://orcid.org/0000-0003-0142-2355
#
# ORCID ID found for "Ott, Melanie" in Pubmed 35945353 :
#  https://orcid.org/0000-0001-8374-669X
#
# ORCID ID found for "Jerby-Arnon, Livnat" in Pubmed 35513526 :
#  https://orcid.org/0000-0002-4037-386X
#      record id save datetime                      biohub author  \
# 0            1      10/10/22                 banfield, jill2414
# 1            2      10/10/22         pisco, angela; neff, norma
# 2            3      10/10/22                          huang, kc
# 3            4      10/10/22                       batson, josh
# 4            5      10/10/22  tato, cristina; greenhouse, bryan
# ..         ...           ...                                ...
# 174        175      10/20/22                   Hernan G. Garcia
# 175        176      10/20/22               Katrin I. Andreasson
# 176        177      10/20/22                   Alanna Schepartz
# 177        178      10/20/22                 Livnat Jerby-Arnon
# 178        179      10/20/22                Mark A Skylar-Scott
#
#     possible biohub author          corresponding author  \
# 0                                    Steven J. Blazewicz
# 1                                            Norma  Neff
# 2                                           Kerwyn Huang
# 3                                            Gytis Dudas
# 4                                         Saki Takahashi
# ..                     ...                           ...
# 174            Elias, Josh                Orion D Weiner
# 175                                    Katrin Andreasson
# 176        Goldberg, Emily              Alanna Schepartz
# 177                              Aviv RegevJesse S Boehm
# 178                         Insoo HyunJeantine E Lunshof
#
#                       corresponding author institution               journal  \
# 0                                                 LLNL               bioRxiv
# 1                               Chan Zuckerberg Biohub               bioRxiv
# 2                                             Stanford               bioRxiv
# 3                                   Vilnius University               bioRxiv
# 4               University of California San Francisco               medRxiv
# ..                                                 ...                   ...
# 174            University of California, San Francisco               bioRxiv
# 175                                Stanford University               bioRxiv
# 176                                        UC Berkeley               bioRxiv
# 177  Broad Institute of Harvard and MIT, Cambridge,...  Nature biotechnology
# 178  Center for Bioethics, Harvard Medical School, ...   Nature neuroscience
#
#                              doi        pmid  \
# 0      10.1101/2022.09.30.510406
# 1      10.1101/2022.03.04.483068
# 2      10.1101/2022.09.01.506215
# 3      10.1101/2022.08.31.505987
# 4    10.1101/2022.09.02.22279519
# ..                           ...         ...
# 174    10.1101/2022.10.17.512504
# 175    10.1101/2022.10.17.512618
# 176    10.1101/2022.10.19.512772
# 177   10.1038/s41587-022-01495-9  36258042.0
# 178   10.1038/s41593-022-01187-2  36258039.0
#
#                                                  title  ...  \
# 0    Isotope-enrichment reveals active viruses foll...  ...
# 1    Concordance of MERFISH Spatial Transcriptomics...  ...
# 2    Antibiotic effects on microbial communities ar...  ...
# 3    Accumulated metagenomic studies reveal recent ...  ...
# 4    Metagenomic next-generation sequencing to char...  ...
# ..                                                 ...  ...
# 174  Decoding of YAP levels and dynamics by pluripo...  ...
# 175  Myeloid deficiency of the intrinsic clock prot...  ...
# 176  Long-term, super-resolution HIDE imaging of th...  ...
# 177  Author Correction: Massively parallel phenotyp...  ...
# 178  How collaboration between bioethicists and neu...  ...
#
#                                                authors  \
# 0    Alexa M. Nicolas; Ella T. Sieradzki; Jennifer ...
# 1    Jonathan Liu; Vanessa Tran; Venkata Naga Prana...
# 2    Daniel Philip Newton; Po-Yi Ho; Kerwyn Casey H...
# 3                           Gytis Dudas; Joshua Batson
# 4    Lusajo Mwakibete; Saki Takahashi; Vida Ahyong;...
# ..                                                 ...
# 174  Kirstin Meyer; Nicholas C. Lammers; Lukasz J. ...
# 175  Chinyere Agbaegbu Iweka; Erica Seigneur; Amira...
# 176  Shuai Zheng; Neville Dadina; Deepto Mozumdar; ...
# 177  Oana Ursu ; James T Neal ; Emily Shea ; Pratik...
# 178  Insoo Hyun ; J C Scharf-Deering ; Sarah Sulliv...
#
#                                               authors2  \
# 0    Nicolas, A. M.; Sieradzki, E. T.; Pett-Ridge, ...
# 1    Liu, J.; Tran, V.; Vemuri, V. N. P.; Byrne, A....
# 2                  Newton, D. P.; Ho, P.-Y.; Huang, K.
# 3                                Dudas, G.; Batson, J.
# 4    Mwakibete, L.; Takahashi, S.; Ahyong, V.; Blac...
# ..                                                 ...
# 174  Meyer, K.; Lammers, N. C.; Bugaj, L. J.; Garci...
# 175  Iweka, C. A.; Seigneur, E. M.; Hernandez, A. L...
# 176  Zheng, S.; Dadina, N.; Mozumdar, D.; Lesiak, L...
# 177
# 178
#
#                                      affiliations list  \
# 0    Plant & Microbial Biology Department, Universi...
# 1    Chan Zuckerberg Biohub; Chan Zuckerberg Biohub...
# 2    Department of Bioengineering, Stanford Univers...
# 3    Institute of Biotechnology, Life Sciences Cent...
# 4    Chan Zuckerberg Biohub; Division of HIV, ID, a...
# ..                                                 ...
# 174  Cardiovascular Research Institute, University ...
# 175  Department of Neurology & Neurological Science...
# 176  Department of Chemistry, University of Califor...
# 177  Broad Institute of Harvard and MIT, Cambridge,...
# 178  Baylor College of Medicine, Houston, TX, USA.;...
#
#                                  author - affiliations published or not  \
# 0    [['Alexa M. Nicolas', 'Plant & Microbial Biolo...
# 1    [['Jonathan Liu', 'Chan Zuckerberg Biohub'], [...
# 2    [['Daniel Philip Newton', 'Department of Bioen...
# 3    [['Gytis Dudas', 'Institute of Biotechnology, ...
# 4    [['Lusajo Mwakibete', 'Chan Zuckerberg Biohub'...
# ..                                                 ...              ...
# 174  [['Kirstin Meyer', 'Cardiovascular Research In...
# 175  [['Chinyere Agbaegbu Iweka', 'Department of Ne...
# 176  [['Shuai Zheng', 'Department of Chemistry, Uni...
# 177  Oana Ursu: Broad Institute of Harvard and MIT,...
# 178  Insoo Hyun: Center for Bioethics, Harvard Medi...
#
#     confirm published doi confirm preprint doi possible match result match id  \
# 0
# 1
# 2
# 3
# 4
# ..                    ...                  ...                   ...      ...
# 174
# 175
# 176
# 177
# 178
#
#     record change number
# 0                      0
# 1                      0
# 2                      0
# 3                      0
# 4                      0
# ..                   ...
# 174                    0
# 175                    0
# 176                    0
# 177                    0
# 178                    0
#
# [179 rows x 30 columns]

# %% [markdown]
# ## 2.版本2.用于preprint的
#
# 除了分号以外的都去掉。比如. , -
#
# if the author record has an ORCID ID, try searching for it in the Biohub Author ORCID ID dictionary
# and alert user if there is a match; ditto if there is an email address
#
#
# 经测试。没有last name=nickname的. middle也没有空的

# %%
def authormatch_pre(df):

    def strip_accents(text):
        try:
            text = unicode(text, 'utf-8')
        except NameError: # unicode is a default on python 3 
            pass

        text = unicodedata.normalize('NFD', text)\
            .encode('ascii', 'ignore')\
            .decode("utf-8")

        return (str(text))

    standard=pd.read_excel('database/Biohub authors.xlsx',
                        dtype = { 
                            'Middle' : str,
                            'ORCID' : str,
                            'Cohort' : str,
                            'Email-Preferred' : str,
                            'Email 2' : str},
                        converters = { 
                            'Ambiguous initials' : lambda x: np.where(x == True, True, False),
                            'Ambiguous incomplete full' : lambda x: np.where(x == True, True, False),
                        })
    standard.dropna(how='all', axis=1,inplace=True)	
    for i in standard.columns[2:7]:
        standard[i]=standard[i].apply(strip_accents).str.lower().replace("[","").replace("]","")

    #use a new df to store
    test=standard.iloc[:,2:7]  #后面可以加上2:9, & email相等的话

    from itertools import permutations 

    for ind,i in enumerate(test['Middle']):
        combines_3=[]
        combines_2=[]
        combines_1=[]
        combines_0=[]
        
        if i=='nmi': # no middle name
            # "FN-NMI" : 3  # firstname lastname  & Lastname firstname
            for result in permutations(test.iloc[ind,1:3], 2):
                combines_3.append(" ".join(result))
            
            # FI-NMI  # firstname[0] lastname  & lastname firstname[0]
            for result in permutations([test.loc[ind,'First Name'][0],test.loc[ind,'Last Name']], 2):
                combines_1.append(" ".join(result))
            
            # #   ？      # firstname lastname[0]  & Lastname[0] firstname
            # for result in permutations([test.loc[ind,'First Name'],test.loc[ind,'Last Name'][0]], 2):
            #     combines.append(" ".join(result))
            
            if (test.loc[ind,'Nickname'] != test.loc[ind,'First Name']):
                # NN-NMI
                for result in permutations([test.loc[ind,'Nickname'],test.loc[ind,'Last Name']], 2):
                    combines_3.append(" ".join(result))
                    
                # for result in permutations([test.loc[ind,'Nickname'],test.loc[ind,'Last Name'][0]], 2):
                #     combines.append(" ".join(result))
                        
        else:
            # FN 
            for result in permutations(test.iloc[ind,1:3], 2):
                combines_2.append(" ".join(result))
                
            # FI-NMI  # firstname[0] lastname  & lastname firstname[0]
            for result in permutations([test.loc[ind,'First Name'][0],test.loc[ind,'Last Name']], 2):
                combines_0.append(" ".join(result))
            
            # FN-MN"            
            combines_3.append(test.loc[ind,'First Name']+' '+test.loc[ind,'Middle'][0]+' '+test.loc[ind,'Last Name'])
            combines_3.append(test.loc[ind,'Last Name']+' '+test.loc[ind,'Middle'][0]+' '+test.loc[ind,'First Name'])
            
            # FN-MI
            combines_3.append(test.loc[ind,'Last Name']+' '+test.loc[ind,'First Name']+' '+test.loc[ind,'Middle'][0])
            
            # FI-MI
            combines_1.append(test.loc[ind,'Last Name']+' '+test.loc[ind,'First Name'][0]+' '+test.loc[ind,'Middle'][0])
            
            if (test.loc[ind,'Nickname'] != test.loc[ind,'First Name']):
                # NN
                for result in permutations([test.loc[ind,'Nickname'],test.loc[ind,'Last Name']], 2):
                    combines_2.append(" ".join(result))
                
            if len(test['Middle'])>1:
                # FN-MN"
                combines_3.append(test.loc[ind,'First Name']+' '+test.loc[ind,'Middle']+' '+test.loc[ind,'Last Name'])
                combines_3.append(test.loc[ind,'Last Name']+' '+test.loc[ind,'Middle']+' '+test.loc[ind,'First Name'])
                
                # FI-MN
                combines_3.append(test.loc[ind,'Last Name']+' '+test.loc[ind,'First Name'][0]+' '+test.loc[ind,'Middle'])
                
        test.loc[ind,'combination3']='; '.join(combines_3)
        test.loc[ind,'combination2']='; '.join(combines_2)
        test.loc[ind,'combination1']='; '.join(combines_1)
        test.loc[ind,'combination0']='; '.join(combines_0)

    test['combination_all']= test['combination0'] + test['combination1'] + test['combination2'] + test['combination3']
    test['combination_23']= test['combination2'] + test['combination3']
    test['combination_01']= test['combination0'] + test['combination1'] 


    df.fillna('', inplace=True)
    preprint_list=['biorxiv','bioRxiv','medrxiv','medRxiv','arxiv','arXiv']
    pre_ind=df[df['journal'].isin(preprint_list)].index
    for ind,i in enumerate(df.loc[pre_ind,'authors']):
        try:
            i=i.split(';')
        except:
            i=i.split(',')

        yes_name_list=list()
        maybe_name_list=list()
        
        for j in i:  # j is every single author name
            j=re.sub(r'[^\w]', ' ', j.strip('#'))
            j=j.replace('  ',' ').strip(' ').replace('-','').lower()

            for ind2 in test.index:
                if j in test.loc[ind2,'combination_01']:
                    x=standard.loc[ind2,'MatchName']
                    maybe_name_list.append(x)
                
                if j in test.loc[ind2,'combination_23']:
                    x=standard.loc[ind2,'MatchName']
                    yes_name_list.append(x)
                    
        df.loc[ind,'possible biohub author']='; '.join(maybe_name_list)
        df.loc[ind,'biohub author']='; '.join(yes_name_list)

    return df

# %%
def strip_accents(text):
    try:
        text = unicode(text, 'utf-8')
    except NameError: # unicode is a default on python 3 
        pass

    text = unicodedata.normalize('NFD', text)\
           .encode('ascii', 'ignore')\
           .decode("utf-8")

    return (str(text))

standard=pd.read_excel('database/Biohub authors.xlsx',
                    dtype = { 
                        'Middle' : str,
                        'ORCID' : str,
                        'Cohort' : str,
                        'Email-Preferred' : str,
                        'Email 2' : str},
                    converters = { 
                        'Ambiguous initials' : lambda x: np.where(x == True, True, False),
                        'Ambiguous incomplete full' : lambda x: np.where(x == True, True, False),
                    })
standard.dropna(how='all', axis=1,inplace=True)	
for i in standard.columns[2:7]:
    standard[i]=standard[i].apply(strip_accents).str.lower().replace("[","").replace("]","")


#储存biohub author所有可能的match
test=standard.iloc[:,2:7]  #后面可以加上2:9, & email相等的话


#经测试。没有last name=nickname的. middle也没有空的

from itertools import permutations 

for ind,i in enumerate(test['Middle']):
    combines_3=[]
    combines_2=[]
    combines_1=[]
    combines_0=[]
    
    if i=='nmi': # no middle name
        # "FN-NMI" : 3  # firstname lastname  & Lastname firstname
        for result in permutations(test.iloc[ind,1:3], 2):
            combines_3.append(" ".join(result))
        
        # FI-NMI  # firstname[0] lastname  & lastname firstname[0]
        for result in permutations([test.loc[ind,'First Name'][0],test.loc[ind,'Last Name']], 2):
            combines_1.append(" ".join(result))
        
        # #   ？      # firstname lastname[0]  & Lastname[0] firstname
        # for result in permutations([test.loc[ind,'First Name'],test.loc[ind,'Last Name'][0]], 2):
        #     combines.append(" ".join(result))
        
        if (test.loc[ind,'Nickname'] != test.loc[ind,'First Name']):
            # NN-NMI
            for result in permutations([test.loc[ind,'Nickname'],test.loc[ind,'Last Name']], 2):
                combines_3.append(" ".join(result))
                
            # for result in permutations([test.loc[ind,'Nickname'],test.loc[ind,'Last Name'][0]], 2):
            #     combines.append(" ".join(result))
                       
    else:
        # FN 
        for result in permutations(test.iloc[ind,1:3], 2):
            combines_2.append(" ".join(result))
            
        # FI-NMI  # firstname[0] lastname  & lastname firstname[0]
        for result in permutations([test.loc[ind,'First Name'][0],test.loc[ind,'Last Name']], 2):
            combines_0.append(" ".join(result))
        
        # FN-MN"            
        combines_3.append(test.loc[ind,'First Name']+' '+test.loc[ind,'Middle'][0]+' '+test.loc[ind,'Last Name'])
        combines_3.append(test.loc[ind,'Last Name']+' '+test.loc[ind,'Middle'][0]+' '+test.loc[ind,'First Name'])
        
        # FN-MI
        combines_3.append(test.loc[ind,'Last Name']+' '+test.loc[ind,'First Name']+' '+test.loc[ind,'Middle'][0])
        
        # FI-MI
        combines_1.append(test.loc[ind,'Last Name']+' '+test.loc[ind,'First Name'][0]+' '+test.loc[ind,'Middle'][0])
        
        if (test.loc[ind,'Nickname'] != test.loc[ind,'First Name']):
            # NN
            for result in permutations([test.loc[ind,'Nickname'],test.loc[ind,'Last Name']], 2):
                combines_2.append(" ".join(result))
             
        if len(test['Middle'])>1:
            # FN-MN"
            combines_3.append(test.loc[ind,'First Name']+' '+test.loc[ind,'Middle']+' '+test.loc[ind,'Last Name'])
            combines_3.append(test.loc[ind,'Last Name']+' '+test.loc[ind,'Middle']+' '+test.loc[ind,'First Name'])
            
            # FI-MN
            combines_3.append(test.loc[ind,'Last Name']+' '+test.loc[ind,'First Name'][0]+' '+test.loc[ind,'Middle'])
            
    test.loc[ind,'combination3']='; '.join(combines_3)
    test.loc[ind,'combination2']='; '.join(combines_2)
    test.loc[ind,'combination1']='; '.join(combines_1)
    test.loc[ind,'combination0']='; '.join(combines_0)

test['combination_all']= test['combination0'] + test['combination1'] + test['combination2'] + test['combination3']
test['combination_23']= test['combination2'] + test['combination3']
test['combination_01']= test['combination0'] + test['combination1']

# %%
df=pd.read_csv('database/basedb.csv', encoding='utf-8-sig')
df.fillna('', inplace=True)

preprint_list=['biorxiv','bioRxiv','medrxiv','medRxiv','arxiv','arXiv']
pre_ind=df[df['journal'].isin(preprint_list)].index
for ind,i in enumerate(df.loc[pre_ind,'authors']):
    try:
        i=i.split(';')
    except:
        i=i.split(',')

    yes_name_list=list()
    maybe_name_list=list()
    
    for j in i:  # j is every single author name
        j=re.sub(r'[^\w]', ' ', j.strip('#'))
        j=j.replace('  ',' ').strip(' ').replace('-','').lower()

        #mat_col=['combination3','combination2','combination1','combination0']
        for ind2 in test.index:
            if j in test.loc[ind2,'combination_01']:
                x=standard.loc[ind2,'MatchName']
                maybe_name_list.append(x)
            
            if j in test.loc[ind2,'combination_23']:
                x=standard.loc[ind2,'MatchName']
                yes_name_list.append(x)
                
    df.loc[ind,'possible biohub author']='; '.join(maybe_name_list)
    df.loc[ind,'biohub author']='; '.join(yes_name_list)

# %% [markdown]
# # 8. pubmde author search
# 每天只搜当天的

# %%
def Pubmed_search_author(start_date,end_date):
    # start_date=end_date
    author=pd.read_excel('database/Biohub authors.xlsx')
    author_list=author['Last Name']+', '+author['First Name']+ '[FAU]'
    df=pd.DataFrame()

    for term in author_list:
        try:
            dt=af.Pubmed_search2(start_date, end_date,TERM=term,save_AuthorInfo=False)
            dt['biohub author']=term.replace('[FAU]','')
            if isinstance(dt, pd.DataFrame):
                df=pd.concat([df,dt],ignore_index=True)
        except:
            pass

    m=list(df.columns)
    m.remove('biohub author')
    df=df.groupby(m)['biohub author'].apply('; '.join).reset_index()      #df2.groupby('pmid', as_index=False).agg(sum)
    df=df.drop_duplicates(subset='pmid', keep="last") # Q: how to drop duplicates then combine 'biohub author column?'
    return df

end=(datetime.date.today() - datetime.timedelta(days=1)).strftime('%Y-%m-%d')
df4 = Pubmed_search_author(start_date=end,end_date=end)
# Out:
# Pubmed: Fetched 1 records in 0.5 seconds.

# %%
df4
# Out:
#                                                title  epost date publish date  \
# 0  Temporal and sequential transcriptional dynami...  2022/11/08    2022/11/9
#
#        pmid                                           abstract  \
# 0  36345783  The cerebral cortex contains billions of neuro...
#
#                         doi  \
# 0  10.15252/embj.2022111132
#
#                                              authors           journal  \
# 0  Tanzila Mukhtar ; Jeremie Breda ; Manal A Adam...  The EMBO journal
#
#                                              keyword  \
# 0  cortical development ; lineage specification ;...
#
#                                         url   biohub author
# 0  https://pubmed.ncbi.nlm.nih.gov/36345783  Harwell, Corey

# %% [markdown]
# # 9.获取coi的方法

# %%
import datetime
import numpy as np
import pandas as pd
import time
import requests
import re
from bs4 import BeautifulSoup as bs
import distance, re
from unidecode import unidecode
import unicodedata
import math
import urllib.parse
import uuid
import xml.etree.ElementTree as ET
from collections import OrderedDict
from itertools import permutations 
from tqdm import tqdm_notebook as tqdm # can remove

# %%
#url='https://pubmed.ncbi.nlm.nih.gov/'+pmid+'/?format=pubmed'
pubmed_url='https://pubmed.ncbi.nlm.nih.gov/36076082/?format=pubmed'

#url_response = requests.get(pubmed_url)
html = bs(requests.get(pubmed_url).text, features='html.parser')
article=html.find('pre')

for i in article.string.replace('\r\n      ','').split('\r\n'):
    if i.startswith('COIS'):
        print(i.replace('COIS- ',''))
# Out:
# P.A.-B.W., E.W. and P.S.K. are named as inventors on a provisional patent application applied for by Stanford University and the Chan Zuckerberg Biohub on coronavirus neutralizing compositions and associated methods. The remaining authors declare no competing interests.

# %%
#这个速度感觉比上一个慢
# way 2
pm_url='https://pubmed.ncbi.nlm.nih.gov/36076082/'

url_response = requests.get(pm_url)
html = bs(url_response.text, features='html.parser')
coi=html.find('div',attrs={'class': 'conflict-of-interest'}).p.text
print(coi)
# Out:
# P.A.-B.W., E.W. and P.S.K. are named as inventors on a provisional patent application applied for by Stanford University and the Chan Zuckerberg Biohub on coronavirus neutralizing compositions and associated methods. The remaining authors declare no competing interests.

# %% [markdown]
# 改进一下
# 1. middle name search
# 2. 作者的对应机构

# %% [markdown]
# # 10.report
# put this in a new page. add side bar.
# create a iterative process.
#
#
# + reference
#
# ## 1. condition: time period
# - check recent report example
# just list publication are by intramural author (only from biohub_author.csv. people only from campus simple = biohub)
#
# list publication & summary statics
#
# ## 2. preprint compliance report  (around 28min'
# number + percentage
# only for inverstagtor. organized by inverstagtor MatchName.
#
# statistic is :
#     how many publication paper they have ,
#     how many publication paper they have they are coressbding author
#     how many publication paper's publication type -> preprint policy apply ( they are research article not a review)
#     how many they have preprint & how many they don't
#     how many preprint they have \ percentage

# %% [markdown]
# # preprint policy
# 1. 出版类型。
#    1. pubmed种有记录 eg  review article 有review这一术语
#    2. 有部分的journal只发表review或者别的我们的政策 not apply to的 （check txt file。 这个文件包括全名和缩写。如果一些文章在这些期刊上发表，那么我们的政策不适用
#        (~df['journal'].isin(review_list))
#
# 2. 当我们运行并生成报告时，我们需要的不仅是
#    1. 摘要统计数据 + 一份详细的报告，     【【一个是出版物列表，另一个是摘要统计】】
#    2. 可以逐个作者查看第一作者，然后逐个记录，
#    3. 对于在首选策略中被称为违规的已发表论文，只需手动管理它们。然后他们可能会说，你知道，当我看记录时，我会说，哦，好吧，出于某种原因，这项政策不适用于此。然后勾选一个字段，表示存在异常。这是个例外。
#       1. 对于报告作者栏：只展示前三个作者，其余改成et al  title (year) 但是不重要！后面在搞。先留个函数的框
#
#
# ## 详细报告：
# 第一行： 加粗的 通讯作者
#
# Author (Year) Title. Journal| Volume|: Pages|. DOI|. PMID: PMID/Accession Number. History: Original Publication|.
#
# List of authors (up to three): LastName, FirstName, Middle Initial ... if there are more than N, than first author only followed by et al. (Year) Title. Journal| Volume|: Pages|. DOI|. PMID: PMID/Accession Number. History: Original Publication|.
#
# Journal = abbreviated version of journal name
#
#
# #
#
# preprint compliance report.

# %%
import all_function as af
import pandas as pd

start='2022-7-01'
end='2022-10-30'

# 1. Select author list 
author=pd.read_excel('database/Biohub authors.xlsx')  #  biohub author

# 需要确定下
intramural=author[author['Campus (simple)'] == 'Biohub']
investigator=author.loc[author['Role'] == 'Investigator']

#author.loc[((author['Campus (simple)'] == 'Biohub') & (author['Role'] == 'Investigator')]
df_a=author.loc[(author['Campus (simple)'] == 'Biohub') | (author['Role'] == 'Investigator') ]


# 2. Choose publication & prerpint within specific time period  # 指定时间内的pub & pre
df = pd.read_csv('database/basedb.csv', encoding='utf-8-sig')
df.fillna('', inplace=True)
#df['date'] = df['date'].str.strip('/6/0').str.split(' ')[0]
#df=af.transfer_date_format(df)


# 2.1 Exclude 'review list'
with open('database/list of review journals.txt') as file:
    review_list = [line.rstrip() for line in file]

df=df[~df['journal'].isin(review_list)]

# 2.2 divided into two categories: publication and preprint
#得把date格式改一下然后。换成date
preprint_list=['biorxiv','bioRxiv','medrxiv','medRxiv','arxiv','arXiv']
preprint = df[df['journal'].isin(preprint_list)]
publication = df[~df['journal'].isin(preprint_list)]

df['epost date'] = pd.to_datetime(df['epost date'])  

pre_condition = (df['epost date'] >= start) & (df['epost date'] <= end) & (df['journal'].isin(preprint_list))
op1_pre=df.loc[pre_condition]

pub_condition = (df['epost date'] >= start) & (df['epost date'] <= end) & (~df['journal'].isin(preprint_list))
op1_pub=df.loc[pub_condition]

# %%
op1="""
Biohub intramural research program – Papers published and preprints first-deposited
{start} ~ {end}:
Includes papers, conference proceedings, and preprints published or first-deposited since the last Biohub All-Hands meeting that cite Biohub affiliation or funding and that include a Biohub employee or close, non-investigator affiliate as a co-author (we may easily have missed something, so please feel free to send Bill Burkholder any additions or corrections)
Papers (Research articles, methods papers, reviews, etc.) and conference proceedings:\n
"""

print(sub(op1))
# Out:
# Biohub intramural research program – Papers published and preprints first-deposited
# 2022-7-01 ~ 2022-10-30:
# Includes papers, conference proceedings, and preprints published or first-deposited since the last Biohub All-Hands meeting that cite Biohub affiliation or funding and that include a Biohub employee or close, non-investigator affiliate as a co-author (we may easily have missed something, so please feel free to send Bill Burkholder any additions or corrections)
# Papers (Research articles, methods papers, reviews, etc.) and conference proceedings:

# %%
from docx import Document

d = Document()
d.add_heading('Biohub intramural research program – Papers published and preprints first-deposited\n ', level=1)


paragraph = d.add_paragraph()
paragraph.add_run('dolor').bold
paragraph.add_run(' and some ')

run = paragraph.add_run('dolor22')
run.bold = True

d.save('docx_file.docx')

# %%
run.bold = True
document.add_heading('Biohub intramural research program – Papers published and preprints first-deposited\n ', level=1)

\033[1mBiohub intramural research program – Papers published and preprints first-deposited
\033[1m{start} ~ {end}:
\033[0mIncludes papers, conference proceedings, and preprints published or first-deposited since the last Biohub All-Hands meeting that cite Biohub affiliation or funding and that include a Biohub employee or close, non-investigator affiliate as a co-author (we may easily have missed something, so please feel free to send Bill Burkholder any additions or corrections)
\n\033[1mPapers (Research articles, methods papers, reviews, etc.) and conference proceedings:\n

# %%
# 3.1 Create detail report
# 输出word



## '\033[1m' bold following text 
## '\033[0m' turn to normal
import sys
class safesub(dict):
    def __missing__(self, key):
        return '{' + key + '}'
def sub(text):
    return text.format_map(safesub(sys._getframe(1).f_locals))

# 3.1.0 heading
op1="""
\033[1mBiohub intramural research program – Papers published and preprints first-deposited
\033[1m{start} ~ {end}:
\033[0mIncludes papers, conference proceedings, and preprints published or first-deposited since the last Biohub All-Hands meeting that cite Biohub affiliation or funding and that include a Biohub employee or close, non-investigator affiliate as a co-author (we may easily have missed something, so please feel free to send Bill Burkholder any additions or corrections)
\n\033[1mPapers (Research articles, methods papers, reviews, etc.) and conference proceedings:\n
"""

# 3.1.1 publication part
for ind,row in op1_pub.iterrows():
    op1 +='\033[1m'+row['biohub author']+row['possible biohub author']+'\n'+'\033[0m   '+row['title']+str(row['pmid'])+'\n\n'

# 3.1.2 preprint part
op1+='\033[1m'+"Preprints:\n"

for ind,row in op1_pre.iterrows():
    op1+='\033[1m'+row['biohub author']+row['possible biohub author']+'\n'+'\033[0m   '+row['title']+str(row['pmid'])+'\n\n'

print(sub(op1))
# Out:
# Biohub intramural research program – Papers published and preprints first-deposited
# 2022-7-01 ~ 2022-10-30:
# Includes papers, conference proceedings, and preprints published or first-deposited since the last Biohub All-Hands meeting that cite Biohub affiliation or funding and that include a Biohub employee or close, non-investigator affiliate as a co-author (we may easily have missed something, so please feel free to send Bill Burkholder any additions or corrections)
#
# Papers (Research articles, methods papers, reviews, etc.) and conference proceedings:
#
# Kristeene A KnoppHanna RetallackJoseph L DeRisiJeremy F Reiter
#    Zika virus alters centrosome organization to suppress the innate immune response.35793002.0
#
# James A Olzmann
#    Context-dependent regulation of ferroptosis sensitivity.35809566.0
#
# Lucy Erin O'Brien
#    Tissue Homeostasis and Non-Homeostasis: From Cell Life Cycles to Organ States.35850152.0
#
# Helen S Bateup
#    Transient food insecurity during the juvenile-adolescent period affects adult weight, cognitive flexibility, and dopamine neurobiology.35863352.0
#
# Sophie Dumont
#    ECM dimensionality tunes actin tension to modulate endoplasmic reticulum function and spheroid phenotypes of mammary epithelial cells.35880301.0
#
# Aashish Manglik
#    Autoantibody mimicry of hormone action at the thyrotropin receptor.35940205.0
#
# Katherine S Pollard
#    Transcription Factor GATA4 Regulates Cell Type-Specific Splicing Through Direct Interaction With RNA in Human Induced Pluripotent Stem Cell-Derived Cardiac Progenitors.35938400.0
#
#
#    Nested epistasis enhancer networks for robust genome regulation.35951677.0
#
# Catherine A Blish
#    Programmable antivirals targeting critical conserved viral RNA secondary structures from influenza A virus and SARS-CoV-2.35982307.0
#
# Michael C LanzLichao ZhangPatrick McAlpineJoshua E Elias
#    Increasing cell size remodels the proteome and promotes senescence.35987199.0
#
# Ada S Y Poon
#    Remotely controlled near-infrared-triggered photothermal treatment of brain tumours in freely behaving mice using gold nanostar﻿s.35995855.0
#
# Alexander Marson
#    RASA2 ablation in T cells boosts antigen sensitivity and long-term function.36002574.0
#
# Hana El-Samad
#    CoRa-A general approach for quantifying biological feedback control.36037352.0
#
# Amy KistlerVida AhyongCristina M TatoJoseph L DeRisi
#    Discovery and Genomic Characterization of a Novel Henipavirus, Angavokely Virus, from Fruit Bats in Madagascar.36040175.0
#
# Angela Oliveira PiscoJames Zou
#    Polygenic enrichment distinguishes disease associations of individual cells in single-cell RNA-seq data.36050550.0
#
# Stephen R Quake
#    Survey of extracellular communication of systemic and organ-specific inflammatory responses through cell free messenger RNA profiling in mice.36054939.0
#
#
#    A bead-based method for high-throughput mapping of the sequence- and force-dependence of T cell activation.36064771.0
#
# Kole T Roybal
#    Diminished cell proliferation promotes natural killer cell adaptive-like phenotype by limiting FcεRIγ expression.36066491.0
#
# Kerwyn Casey Huang
#    M-TUBE enables large-volume bacterial gene delivery using a high-throughput microfluidic electroporation platform.36067229.0
#
# Katherine S Pollard
#    Enhancer Function and Evolutionary Roles of Human Accelerated Regions.36070559.0
#
# Helen S BateupDirk Hockemeyer
#    Highly efficient generation of isogenic pluripotent stem cell models using prime editing.36069759.0
#
# Kerwyn Casey Huang
#    Fatty Acid Synthesis Knockdown Promotes Biofilm Wrinkling and Inhibits Sporulation in Bacillus subtilis.36069446.0
#
# Sunit JainFeiqiao B YuXiandong MengAllison WeakleyJia YanNorma NeffJustin L SonnenburgKerwyn Casey HuangMichael A Fischbach
#    Design, construction, and in vivo augmentation of a complex gut microbiome.36070752.0
#
# Melanie Ott
#    Structure-function analysis of enterovirus protease 2A in complex with its essential host factor SETD3.36075902.0
#
# Carlos D Bustamante
#    Validating and automating learning of cardiometabolic polygenic risk scores from direct-to-consumer genetic and phenotypic data: implications for scaling precision health research.36076307.0
#
# Eric WaltariJohn E PakPeter S Kim
#    Converting non-neutralizing SARS-CoV-2 antibodies into broad-spectrum inhibitors.36076082.0
#
# Melanie Ott
#    SIRT5 is a proviral factor that interacts with SARS-CoV-2 Nsp14 protein.36095012.0
#
# Anthea MitchellChung Yu WangJoseph L DeRisi
#    Low Prevalence of Interferon-α Autoantibodies in People Experiencing Long COVID Symptoms.36089700.0
#
# H Tom Soh
#    Improved immunoassay sensitivity and specificity using single-molecule colocalization.36097164.0
#
# Charles R Langelier
#    Plasma SARS-CoV-2 nucleocapsid antigen levels are associated with progression to severe disease in hospitalized COVID-19.36104754.0
#
# Christina D Smolke
#    Highly multiplexed selection of RNA aptamers against a small molecule library.36107884.0
#
# Eric WaltariSaba NafeesKrista M McCutcheonJoan WongJohn E Pak
#    AIRRscape: An interactive tool for exploring B-cell receptor repertoires and antibody responses.36126074.0
#
#
#    Anthroponumbers.org: A quantitative database of human impacts on Planet Earth.36124305.0
#
# Katherine S PollardPeter J Turnbaugh
#    Host and gut bacteria share metabolic pathways for anti-cancer drug metabolism.36138165.0
#
# Michael C LanzFrank McCarthyJoshua E EliasJan M Skotheim
#    Delineation of proteome changes driven by cell size and growth rate.36133920.0
#
# Catherine A Blish
#    SARS-CoV-2 infection drives an inflammatory response in human adipose tissue through infection of adipocytes and macrophages.36137009.0
#
# James A Olzmann
#    VPS13A and VPS13C Influence Lipid Droplet Abundance.36147729.0
#
# Guillaume Le TreutGreg HuberMason KambAaron McGeeverDavid Yllanes
#    A high-resolution flux-matrix model describes the spread of diseases in a spatial network and the effect of mitigation strategies.36153391.0
#
# Rui YanAlexander A ChoiKe Xu
#    Fluorogenic Dimers as Bright Switchable Probes for Enhanced Super-Resolution Imaging of Cell Membranes.36153973.0
#
# Pascal Geldsetzer
#    Addressing alcohol use among blood pressure patients in Thai primary care: Lessons from a survey-based stakeholder consultation.36161118.0
#
# Peter S Kim
#    Human sperm TMEM95 binds eggs and facilitates membrane fusion.36161911.0
#
# Charles Gawad
#    Single-cell genome sequencing of human neurons identifies somatic point mutation and indel enrichment in regulatory elements.36163278.0
#
# Christina D Smolke
#    Modulating myoblast differentiation with RNA-based controllers.36166456.0
#
# Polly M FordyceStephen R Quake
#    Metasurface optofluidics for dynamic control of light fields.36163507.0
#
# Chun Jimmie Ye
#    Multi-context genetic modeling of transcriptional regulation resolves novel disease loci.36171194.0
#
# Helen S Bateup
#    A nomenclature consensus for nervous system organoids and assembloids.36171373.0
#
# Jillian F Banfield
#    Experimental validation that human microbiome phages use alternative genetic coding.36175428.0
#
# Emma Lundberg
#    Analysis of the Human Protein Atlas Weakly Supervised Single-Cell Classification competition.36175767.0
#
#
#    Evolution of cell size control is canalized towards adders or sizers by cell cycle structure and selective pressures.36178345.0
#
# Joseph L DeRisi
#    Genomic analysis, immunomodulation and deep phenotyping of patients with nodding syndrome.36181424.0
#
# Catherine Blish
#    CyTOF analysis identifies unusual immune cells in urine of BCG-treated bladder cancer patients.36189320.0
#
# Kerwyn Casey Huang
#    Feedback linking cell envelope stiffness, curvature, and synthesis enables robust rod-shaped bacterial growth.36191183.0
#
#
#    Selection of rAAV vectors that cross the human blood-brain barrier and target the central nervous system using a transwell model.36186955.0
#
# Andreas S Puschnik
#    The human disease gene LYSET is essential for lysosomal enzyme transport and viral infection.36074821.0
#
# Anthea MitchellChung-Yu WangJoseph DeRisi
#    COVID-19 Symptoms and Duration of Rapid Antigen Test Positivity at a Community Testing and Surveillance Site During Pre-Delta, Delta, and Omicron BA.1 Periods.36215069.0
#
# Shuo HanAlice Y Ting
#    In situ cell-type-specific cell-surface proteomic profiling in mice.36220098.0
#
# Stephen R Quake
#    Heterologous reporter expression in the planarian 36313809.0
#
# Preprints:
#
#    Development and Clinical Evaluation of an AI Support Tool for Improving Telemedicine Photo Quality
#
#
#    Towards General-Purpose Representation Learning of Polygonal Geometries
#
#
#    Generalizing Bayesian Optimization with Decision-theoretic Entropies
#
#
#    Exploration via Planning for Information about the Optimal Trajectory
#
#
#    AutoML for Climate Change: A Call to Action
#
#
#    Domain-guided data augmentation for deep learning on medical imaging
#
#
#    Label-free segmentation from cardiac ultrasound using self-supervised learning
#
#
#    Deep Bidirectional Language-Knowledge Graph Pretraining
#
#
#    Phase transition in the computational complexity of the shortest common superstring and genome assembly

# %% [markdown]
# ## CREATE DF report

# %%
             Biohub staff authors    All authors
Papers (Research articles, methods papers, reviews, etc.) and conference proceedings
Preprints
Total

# %%
b_au=df_a['MatchName'].str.replace(',','').values.tolist()

df[df['biohub author'].isin(b_au)]
# Out:
# Empty DataFrame
# Columns: [record id, save datetime, biohub author, possible biohub author, corresponding author, corresponding author institution, journal, doi, pmid, title, url, abstract, keyword, pdf url, version, version number, type, date, epost date, publish date, authors, authors2, affiliations list, author - affiliations, published or not, confirm published doi, confirm preprint doi, possible match result, match id, record change number]
# Index: []
#
# [0 rows x 30 columns]

# %%
df2=pd.DataFrame(columns =['Biohub staff authors', 'All authors'],index = ['Papers (Research articles, methods papers, reviews, etc.) and conference proceedings', 'Preprints', 'Total'])

df2.iloc[0,1]=op1_pub.shape[0]
df2.iloc[1,1]=op1_pre.shape[0]
df2.iloc[2,1]=df2.iloc[0,1]+df2.iloc[1,1]

df2.iloc[0,0]=op1_pub[(op1_pub['biohub author']!='') | (op1_pub['possible biohub author']!='')].shape[0]
df2.iloc[1,0]=op1_pre[(op1_pre['biohub author']!='') | (op1_pre['possible biohub author']!='')].shape[0]
df2.iloc[2,0]=df2.iloc[0,0]+df2.iloc[1,0]


print("Papers published and preprints first-deposited from",start,'to',end)
df2
# Out:
# Papers published and preprints first-deposited from 2022-7-01 to 2022-10-30
#                                                    Biohub staff authors  \
# Papers (Research articles, methods papers, revi...                   52
# Preprints                                                             0
# Total                                                                52
#
#                                                    All authors
# Papers (Research articles, methods papers, revi...          57
# Preprints                                                    9
# Total                                                       66

# %% [markdown]
# ### 表3

# %%
df3=df.iloc[df[df['b_au']!=''].index,:]
df3['b_au'] = df3['b_au'].map(lambda x:x.split(', '))  # Q: split by '; '
df3=df3.explode('b_au')
t=pd.DataFrame(df3.groupby('b_au')['record id'].count()).rename(columns={'record id':'Compliance'}) 
t.index.name = None
#t=t[t.index.isin(author['MatchName'])]

p3=pd.DataFrame(columns =['Total articles as corresponding author','Qualifying articles as corresponding author','Qualifying articles as corresponding author with preprints','Compliance'],index = author['MatchName'])
p3.index.name = None
p3['Compliance'].fillna(t['Compliance'])
# Out:
# /var/folders/3c/40ljyfqs6z97lnyy1drkzt9w0000gn/T/ipykernel_26138/2488453276.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['b_au'] = df3['b_au'].map(lambda x:x.split(', '))  # Q: split by '; '

# %% [markdown]
# preprint policy 标准:
#     publication type
#         1 pubmed: review article
#             /PublicationTypeList
#             if publication belong to this journal（看bill发的文件）, we can say the preprint policy is not apply
#         2 personal curation

# %%
# 7. 加两个按钮来输出报告 & report

start=

# %% [markdown]
# # 8. 加登录界面。只有特定的人才能修改。
# 	eg。 只能用biohub的邮箱注册

# %% [markdown]
# # 8. author的csv也得保证更新是那种的

# %% [markdown]
# 把 award date放进author csv

# %% [markdown]
# # 加citation - 失败。bill说先搁置

# %% [markdown]
# # author match找到missing的之后可以把他replace一下呢
